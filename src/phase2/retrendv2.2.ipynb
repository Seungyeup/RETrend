# %%
import duckdb, glob, os

home        = os.path.expanduser("~")
raw         = os.path.join(home, "dev/RETrend")
parquet_dir = os.path.join(raw, "parquet")
os.makedirs(parquet_dir, exist_ok=True)

con = duckdb.connect()

for csv_fp in glob.glob(os.path.join(raw, "trade_history/", "trade_history_*.csv")):
    fn        = os.path.basename(csv_fp)
    complexNo = int(fn.split("_")[2].split(".")[0])
    pq_fp     = os.path.join(parquet_dir, f"trade_history_{complexNo}.parquet")

    # 1) 변환 실패 행만 먼저 뽑아서 출력
    bad_rows = con.execute(f"""
      SELECT *
      FROM read_csv_auto('{csv_fp}')
      WHERE TRY_CAST(tradeDate AS BIGINT) IS NULL
         OR TRY_CAST(tradeYear AS BIGINT) IS NULL
         OR TRY_CAST(tradeMonth AS BIGINT) IS NULL
         OR TRY_CAST(dealPrice AS BIGINT) IS NULL
         OR TRY_CAST(floor AS BIGINT) IS NULL
         OR TRY_CAST(representativeArea AS DOUBLE) IS NULL
         OR TRY_CAST(exclusiveArea AS DOUBLE) IS NULL
         OR TRY_CAST(areaNo AS BIGINT) IS NULL
    """).fetchall()

    for row in bad_rows:
        print(f"⚠️ 건너뛸 행 ({fn}):", row)

    # 2) 유효한 행만 Parquet으로 저장
    con.execute(f"""
      COPY (
        SELECT
          tradeType::VARCHAR                              AS tradeType,
          CAST(tradeYear       AS BIGINT)                 AS tradeYear,
          CAST(tradeMonth      AS BIGINT)                 AS tradeMonth,
          CAST(tradeDate       AS BIGINT)                 AS tradeDate,
          CAST(dealPrice       AS BIGINT)                 AS dealPrice,
          CAST(floor           AS BIGINT)                 AS floor,
          CAST(representativeArea AS DOUBLE)              AS representativeArea,
          CAST(exclusiveArea   AS DOUBLE)                 AS exclusiveArea,
          formattedPrice::VARCHAR                         AS formattedPrice,
          formattedTradeYearMonth::VARCHAR                AS formattedTradeYearMonth,
          CAST(areaNo         AS BIGINT)                  AS areaNo,
          CAST({complexNo}    AS BIGINT)                  AS complexNo,
          CAST(
            lpad(tradeYear::VARCHAR,4,'0') || '-' ||
            lpad(tradeMonth::VARCHAR,2,'0') || '-' ||
            lpad(tradeDate::VARCHAR,2,'0')
            AS TIMESTAMP
          )                                              AS date
        FROM read_csv_auto('{csv_fp}')
        WHERE TRY_CAST(tradeDate       AS BIGINT) IS NOT NULL
          AND TRY_CAST(tradeYear       AS BIGINT) IS NOT NULL
          AND TRY_CAST(tradeMonth      AS BIGINT) IS NOT NULL
          AND TRY_CAST(dealPrice       AS BIGINT) IS NOT NULL
          AND TRY_CAST(floor           AS BIGINT) IS NOT NULL
          AND TRY_CAST(representativeArea AS DOUBLE) IS NOT NULL
          AND TRY_CAST(exclusiveArea   AS DOUBLE) IS NOT NULL
          AND TRY_CAST(areaNo         AS BIGINT) IS NOT NULL
      )
      TO '{pq_fp}' (FORMAT PARQUET, COMPRESSION 'snappy');
    """)
    print("✅ CSV→Parquet:", fn)

con.close()
# Out:
# ✅ CSV→Parquet: trade_history_1040.csv
# ✅ CSV→Parquet: trade_history_113997.csv
# ✅ CSV→Parquet: trade_history_102642.csv
# ✅ CSV→Parquet: trade_history_144617.csv
# ✅ CSV→Parquet: trade_history_785.csv
# ✅ CSV→Parquet: trade_history_143178.csv
# ✅ CSV→Parquet: trade_history_132781.csv
# ✅ CSV→Parquet: trade_history_22573.csv
# ✅ CSV→Parquet: trade_history_8702.csv
# ✅ CSV→Parquet: trade_history_3657.csv
# ✅ CSV→Parquet: trade_history_160979.csv
# ✅ CSV→Parquet: trade_history_108409.csv
# ✅ CSV→Parquet: trade_history_110246.csv
# ✅ CSV→Parquet: trade_history_4138.csv
# ✅ CSV→Parquet: trade_history_2549.csv
# ✅ CSV→Parquet: trade_history_150662.csv
# ✅ CSV→Parquet: trade_history_26715.csv
# ✅ CSV→Parquet: trade_history_116637.csv
# ✅ CSV→Parquet: trade_history_26073.csv
# ✅ CSV→Parquet: trade_history_4886.csv
# ✅ CSV→Parquet: trade_history_116151.csv
# ✅ CSV→Parquet: trade_history_109071.csv
# ✅ CSV→Parquet: trade_history_106342.csv
# ✅ CSV→Parquet: trade_history_5540.csv
# ✅ CSV→Parquet: trade_history_110520.csv
# ✅ CSV→Parquet: trade_history_11807.csv
# ✅ CSV→Parquet: trade_history_3131.csv
# ✅ CSV→Parquet: trade_history_24664.csv
# ✅ CSV→Parquet: trade_history_7357.csv
# ✅ CSV→Parquet: trade_history_142500.csv
# ✅ CSV→Parquet: trade_history_124685.csv
# ✅ CSV→Parquet: trade_history_6049.csv
# ✅ CSV→Parquet: trade_history_22215.csv
# ✅ CSV→Parquet: trade_history_112337.csv
# ✅ CSV→Parquet: trade_history_115458.csv
# ✅ CSV→Parquet: trade_history_1726.csv
# ✅ CSV→Parquet: trade_history_114752.csv
# ✅ CSV→Parquet: trade_history_105887.csv
# ✅ CSV→Parquet: trade_history_104541.csv
# ✅ CSV→Parquet: trade_history_8070.csv
# ✅ CSV→Parquet: trade_history_22201.csv
# ✅ CSV→Parquet: trade_history_116145.csv
# ✅ CSV→Parquet: trade_history_26067.csv
# ✅ CSV→Parquet: trade_history_126086.csv
# ✅ CSV→Parquet: trade_history_5554.csv
# ✅ CSV→Parquet: trade_history_110534.csv
# ✅ CSV→Parquet: trade_history_3125.csv
# ✅ CSV→Parquet: trade_history_27379.csv
# ✅ CSV→Parquet: trade_history_100041.csv
# ✅ CSV→Parquet: trade_history_3643.csv
# ✅ CSV→Parquet: trade_history_157119.csv
# ✅ CSV→Parquet: trade_history_137835.csv
# ✅ CSV→Parquet: trade_history_5232.csv
# ✅ CSV→Parquet: trade_history_26701.csv
# ✅ CSV→Parquet: trade_history_25208.csv
# ✅ CSV→Parquet: trade_history_791.csv
# ✅ CSV→Parquet: trade_history_102656.csv
# ✅ CSV→Parquet: trade_history_1054.csv
# ✅ CSV→Parquet: trade_history_13962.csv
# ✅ CSV→Parquet: trade_history_105139.csv
# ✅ CSV→Parquet: trade_history_9408.csv
# ✅ CSV→Parquet: trade_history_104227.csv
# ✅ CSV→Parquet: trade_history_7425.csv
# ✅ CSV→Parquet: trade_history_8716.csv
# ✅ CSV→Parquet: trade_history_123698.csv
# ✅ CSV→Parquet: trade_history_103548.csv
# ✅ CSV→Parquet: trade_history_27437.csv
# ✅ CSV→Parquet: trade_history_108435.csv
# ✅ CSV→Parquet: trade_history_11185.csv
# ✅ CSV→Parquet: trade_history_119538.csv
# ✅ CSV→Parquet: trade_history_101377.csv
# ✅ CSV→Parquet: trade_history_2575.csv
# ✅ CSV→Parquet: trade_history_9420.csv
# ✅ CSV→Parquet: trade_history_143144.csv
# ✅ CSV→Parquet: trade_history_6713.csv
# ✅ CSV→Parquet: trade_history_961.csv
# ✅ CSV→Parquet: trade_history_23651.csv
# ✅ CSV→Parquet: trade_history_103560.csv
# ✅ CSV→Parquet: trade_history_13792.csv
# ✅ CSV→Parquet: trade_history_24658.csv
# ✅ CSV→Parquet: trade_history_23137.csv
# ✅ CSV→Parquet: trade_history_104569.csv
# ✅ CSV→Parquet: trade_history_9346.csv
# ✅ CSV→Parquet: trade_history_6075.csv
# ✅ CSV→Parquet: trade_history_14943.csv
# ✅ CSV→Parquet: trade_history_115464.csv
# ✅ CSV→Parquet: trade_history_2213.csv
# ✅ CSV→Parquet: trade_history_107060.csv
# ✅ CSV→Parquet: trade_history_27351.csv
# ✅ CSV→Parquet: trade_history_118140.csv
# ✅ CSV→Parquet: trade_history_116179.csv
# ✅ CSV→Parquet: trade_history_2207.csv
# ✅ CSV→Parquet: trade_history_5568.csv
# ✅ CSV→Parquet: trade_history_16198.csv
# ✅ CSV→Parquet: trade_history_111616.csv
# ✅ CSV→Parquet: trade_history_107074.csv
# ✅ CSV→Parquet: trade_history_167958.csv
# ✅ CSV→Parquet: trade_history_110508.csv
# ✅ CSV→Parquet: trade_history_27345.csv
# ✅ CSV→Parquet: trade_history_118154.csv
# ✅ CSV→Parquet: trade_history_9352.csv
# ✅ CSV→Parquet: trade_history_24894.csv
# ✅ CSV→Parquet: trade_history_25552.csv
# ✅ CSV→Parquet: trade_history_1068.csv
# ✅ CSV→Parquet: trade_history_115316.csv
# ✅ CSV→Parquet: trade_history_9434.csv
# ✅ CSV→Parquet: trade_history_6707.csv
# ✅ CSV→Parquet: trade_history_105105.csv
# ✅ CSV→Parquet: trade_history_143150.csv
# ✅ CSV→Parquet: trade_history_975.csv
# ✅ CSV→Parquet: trade_history_23645.csv
# ✅ CSV→Parquet: trade_history_13786.csv
# ✅ CSV→Parquet: trade_history_27423.csv
# ✅ CSV→Parquet: trade_history_118632.csv
# ✅ CSV→Parquet: trade_history_107712.csv
# ✅ CSV→Parquet: trade_history_108421.csv
# ✅ CSV→Parquet: trade_history_111170.csv
# ✅ CSV→Parquet: trade_history_128929.csv
# ✅ CSV→Parquet: trade_history_11191.csv
# ✅ CSV→Parquet: trade_history_2561.csv
# ✅ CSV→Parquet: trade_history_101363.csv
# ✅ CSV→Parquet: trade_history_118801.csv
# ✅ CSV→Parquet: trade_history_16615.csv
# ✅ CSV→Parquet: trade_history_19526.csv
# ⚠️ 건너뛸 행 (trade_history_141974.csv): ('A1', 2009, 6, '11~20', 8500, 3, 0.0, 0.0, '8,500', '2009.06.11~20', 1)
# ⚠️ 건너뛸 행 (trade_history_141974.csv): ('A1', 2009, 6, '11~20', 8500, 7, 0.0, 0.0, '8,500', '2009.06.11~20', 1)
# ⚠️ 건너뛸 행 (trade_history_141974.csv): ('A1', 2009, 4, '21~30', 8500, 8, 0.0, 0.0, '8,500', '2009.04.21~30', 1)
# ⚠️ 건너뛸 행 (trade_history_141974.csv): ('A1', 2009, 4, '21~30', 8500, 7, 0.0, 0.0, '8,500', '2009.04.21~30', 1)
# ⚠️ 건너뛸 행 (trade_history_141974.csv): ('A1', 2009, 4, '21~30', 8500, 8, 0.0, 0.0, '8,500', '2009.04.21~30', 1)
# ⚠️ 건너뛸 행 (trade_history_141974.csv): ('A1', 2009, 4, '1~10', 8000, 6, 0.0, 0.0, '8,000', '2009.04.1~10', 1)
# ⚠️ 건너뛸 행 (trade_history_141974.csv): ('A1', 2009, 3, '11~20', 10000, 5, 0.0, 0.0, '1억', '2009.03.11~20', 1)
# ⚠️ 건너뛸 행 (trade_history_141974.csv): ('A1', 2008, 11, '11~20', 11000, 4, 0.0, 0.0, '1억 1,000', '2008.11.11~20', 1)
# ⚠️ 건너뛸 행 (trade_history_141974.csv): ('A1', 2008, 11, '1~10', 10000, 1, 0.0, 0.0, '1억', '2008.11.1~10', 1)
# ⚠️ 건너뛸 행 (trade_history_141974.csv): ('A1', 2008, 11, '1~10', 10000, 1, 0.0, 0.0, '1억', '2008.11.1~10', 1)
# ⚠️ 건너뛸 행 (trade_history_141974.csv): ('A1', 2008, 11, '1~10', 10000, 2, 0.0, 0.0, '1억', '2008.11.1~10', 1)
# ⚠️ 건너뛸 행 (trade_history_141974.csv): ('A1', 2008, 11, '1~10', 10000, 2, 0.0, 0.0, '1억', '2008.11.1~10', 1)
# ⚠️ 건너뛸 행 (trade_history_141974.csv): ('A1', 2008, 10, '11~20', 11000, 5, 0.0, 0.0, '1억 1,000', '2008.10.11~20', 1)
# ⚠️ 건너뛸 행 (trade_history_141974.csv): ('A1', 2008, 10, '1~10', 10000, 9, 0.0, 0.0, '1억', '2008.10.1~10', 1)
# ⚠️ 건너뛸 행 (trade_history_141974.csv): ('A1', 2008, 7, '1~10', 10500, 6, 0.0, 0.0, '1억 500', '2008.07.1~10', 1)
# ✅ CSV→Parquet: trade_history_141974.csv
# ✅ CSV→Parquet: trade_history_3694.csv
# ✅ CSV→Parquet: trade_history_10264.csv
# ✅ CSV→Parquet: trade_history_127429.csv
# ✅ CSV→Parquet: trade_history_6934.csv
# ✅ CSV→Parquet: trade_history_12473.csv
# ✅ CSV→Parquet: trade_history_746.csv
# ✅ CSV→Parquet: trade_history_8919.csv
# ✅ CSV→Parquet: trade_history_1083.csv
# ✅ CSV→Parquet: trade_history_112492.csv
# ✅ CSV→Parquet: trade_history_105688.csv
# ✅ CSV→Parquet: trade_history_105850.csv
# ✅ CSV→Parquet: trade_history_104596.csv
# ✅ CSV→Parquet: trade_history_111825.csv
# ✅ CSV→Parquet: trade_history_120420.csv
# ✅ CSV→Parquet: trade_history_136242.csv
# ✅ CSV→Parquet: trade_history_19240.csv
# ✅ CSV→Parquet: trade_history_106381.csv
# ✅ CSV→Parquet: trade_history_129362.csv
# ✅ CSV→Parquet: trade_history_5583.csv
# ✅ CSV→Parquet: trade_history_17279.csv
# ✅ CSV→Parquet: trade_history_4689.csv
# ✅ CSV→Parquet: trade_history_11608.csv
# ✅ CSV→Parquet: trade_history_16167.csv
# ✅ CSV→Parquet: trade_history_5597.csv
# ✅ CSV→Parquet: trade_history_114949.csv
# ✅ CSV→Parquet: trade_history_14770.csv
# ✅ CSV→Parquet: trade_history_124134.csv
# ✅ CSV→Parquet: trade_history_13779.csv
# ✅ CSV→Parquet: trade_history_122545.csv
# ✅ CSV→Parquet: trade_history_102695.csv
# ✅ CSV→Parquet: trade_history_1097.csv
# ✅ CSV→Parquet: trade_history_113940.csv
# ✅ CSV→Parquet: trade_history_752.csv
# ✅ CSV→Parquet: trade_history_3858.csv
# ✅ CSV→Parquet: trade_history_118815.csv
# ✅ CSV→Parquet: trade_history_19532.csv
# ✅ CSV→Parquet: trade_history_107935.csv
# ✅ CSV→Parquet: trade_history_3680.csv
# ✅ CSV→Parquet: trade_history_10270.csv
# ✅ CSV→Parquet: trade_history_116838.csv
# ✅ CSV→Parquet: trade_history_23692.csv
# ✅ CSV→Parquet: trade_history_102865.csv
# ✅ CSV→Parquet: trade_history_13751.csv
# ✅ CSV→Parquet: trade_history_8925.csv
# ✅ CSV→Parquet: trade_history_15320.csv
# ✅ CSV→Parquet: trade_history_125202.csv
# ✅ CSV→Parquet: trade_history_13989.csv
# ✅ CSV→Parquet: trade_history_16629.csv
# ✅ CSV→Parquet: trade_history_3870.csv
# ✅ CSV→Parquet: trade_history_121064.csv
# ✅ CSV→Parquet: trade_history_10258.csv
# ✅ CSV→Parquet: trade_history_26932.csv
# ✅ CSV→Parquet: trade_history_18604.csv
# ✅ CSV→Parquet: trade_history_161440.csv
# ✅ CSV→Parquet: trade_history_17537.csv
# ✅ CSV→Parquet: trade_history_18162.csv
# ✅ CSV→Parquet: trade_history_17251.csv
# ✅ CSV→Parquet: trade_history_108390.csv
# ✅ CSV→Parquet: trade_history_127373.csv
# ✅ CSV→Parquet: trade_history_27392.csv
# ✅ CSV→Parquet: trade_history_111819.csv
# ✅ CSV→Parquet: trade_history_11620.csv
# ✅ CSV→Parquet: trade_history_168464.csv
# ✅ CSV→Parquet: trade_history_100914.csv
# ✅ CSV→Parquet: trade_history_9385.csv
# ✅ CSV→Parquet: trade_history_143839.csv
# ✅ CSV→Parquet: trade_history_1901.csv
# ✅ CSV→Parquet: trade_history_14758.csv
# ✅ CSV→Parquet: trade_history_9391.csv
# ✅ CSV→Parquet: trade_history_24857.csv
# ✅ CSV→Parquet: trade_history_114975.csv
# ✅ CSV→Parquet: trade_history_25591.csv
# ✅ CSV→Parquet: trade_history_123101.csv
# ✅ CSV→Parquet: trade_history_13023.csv
# ✅ CSV→Parquet: trade_history_1915.csv
# ✅ CSV→Parquet: trade_history_17245.csv
# ✅ CSV→Parquet: trade_history_27386.csv
# ✅ CSV→Parquet: trade_history_118197.csv
# ✅ CSV→Parquet: trade_history_26098.csv
# ✅ CSV→Parquet: trade_history_11634.csv
# ✅ CSV→Parquet: trade_history_3864.csv
# ✅ CSV→Parquet: trade_history_118829.csv
# ✅ CSV→Parquet: trade_history_11152.csv
# ✅ CSV→Parquet: trade_history_18610.csv
# ✅ CSV→Parquet: trade_history_26926.csv
# ✅ CSV→Parquet: trade_history_17523.csv
# ✅ CSV→Parquet: trade_history_23686.csv
# ✅ CSV→Parquet: trade_history_13745.csv
# ✅ CSV→Parquet: trade_history_1524.csv
# ✅ CSV→Parquet: trade_history_25778.csv
# ✅ CSV→Parquet: trade_history_9178.csv
# ✅ CSV→Parquet: trade_history_180457.csv
# ✅ CSV→Parquet: trade_history_105449.csv
# ✅ CSV→Parquet: trade_history_8266.csv
# ✅ CSV→Parquet: trade_history_103038.csv
# ✅ CSV→Parquet: trade_history_114544.csv
# ✅ CSV→Parquet: trade_history_3333.csv
# ✅ CSV→Parquet: trade_history_19081.csv
# ✅ CSV→Parquet: trade_history_140115.csv
# ✅ CSV→Parquet: trade_history_148549.csv
# ✅ CSV→Parquet: trade_history_150306.csv
# ✅ CSV→Parquet: trade_history_26271.csv
# ✅ CSV→Parquet: trade_history_101149.csv
# ✅ CSV→Parquet: trade_history_106626.csv
# ✅ CSV→Parquet: trade_history_5024.csv
# ✅ CSV→Parquet: trade_history_109515.csv
# ✅ CSV→Parquet: trade_history_2993.csv
# ✅ CSV→Parquet: trade_history_3455.csv
# ✅ CSV→Parquet: trade_history_24300.csv
# ✅ CSV→Parquet: trade_history_142064.csv
# ✅ CSV→Parquet: trade_history_103986.csv
# ✅ CSV→Parquet: trade_history_587.csv
# ✅ CSV→Parquet: trade_history_102440.csv
# ✅ CSV→Parquet: trade_history_1242.csv
# ✅ CSV→Parquet: trade_history_122790.csv
# ✅ CSV→Parquet: trade_history_8514.csv
# ✅ CSV→Parquet: trade_history_22765.csv
# ✅ CSV→Parquet: trade_history_103992.csv
# ✅ CSV→Parquet: trade_history_6539.csv
# ✅ CSV→Parquet: trade_history_1256.csv
# ✅ CSV→Parquet: trade_history_593.csv
# ✅ CSV→Parquet: trade_history_144401.csv
# ✅ CSV→Parquet: trade_history_115128.csv
# ✅ CSV→Parquet: trade_history_26503.csv
# ✅ CSV→Parquet: trade_history_109501.csv
# ✅ CSV→Parquet: trade_history_2987.csv
# ✅ CSV→Parquet: trade_history_3441.csv
# ✅ CSV→Parquet: trade_history_100525.csv
# ✅ CSV→Parquet: trade_history_3327.csv
# ✅ CSV→Parquet: trade_history_108179.csv
# ✅ CSV→Parquet: trade_history_106154.csv
# ✅ CSV→Parquet: trade_history_166878.csv
# ✅ CSV→Parquet: trade_history_26265.csv
# ✅ CSV→Parquet: trade_history_119074.csv
# ✅ CSV→Parquet: trade_history_1530.csv
# ✅ CSV→Parquet: trade_history_144367.csv
# ✅ CSV→Parquet: trade_history_112121.csv
# ✅ CSV→Parquet: trade_history_143408.csv
# ✅ CSV→Parquet: trade_history_124493.csv
# ✅ CSV→Parquet: trade_history_8272.csv
# ✅ CSV→Parquet: trade_history_115896.csv
# ✅ CSV→Parquet: trade_history_146558.csv
# ✅ CSV→Parquet: trade_history_117071.csv
# ✅ CSV→Parquet: trade_history_108151.csv
# ✅ CSV→Parquet: trade_history_107262.csv
# ✅ CSV→Parquet: trade_history_4460.csv
# ✅ CSV→Parquet: trade_history_111400.csv
# ✅ CSV→Parquet: trade_history_10927.csv
# ✅ CSV→Parquet: trade_history_101613.csv
# ✅ CSV→Parquet: trade_history_25744.csv
# ✅ CSV→Parquet: trade_history_1518.csv
# ✅ CSV→Parquet: trade_history_105475.csv
# ✅ CSV→Parquet: trade_history_6277.csv
# ✅ CSV→Parquet: trade_history_112109.csv
# ✅ CSV→Parquet: trade_history_7169.csv
# ✅ CSV→Parquet: trade_history_155242.csv
# ✅ CSV→Parquet: trade_history_14599.csv
# ✅ CSV→Parquet: trade_history_103004.csv
# ✅ CSV→Parquet: trade_history_23453.csv
# ✅ CSV→Parquet: trade_history_6511.csv
# ✅ CSV→Parquet: trade_history_9622.csv
# ✅ CSV→Parquet: trade_history_2777.csv
# ✅ CSV→Parquet: trade_history_11387.csv
# ✅ CSV→Parquet: trade_history_116409.csv
# ✅ CSV→Parquet: trade_history_109529.csv
# ✅ CSV→Parquet: trade_history_5018.csv
# ✅ CSV→Parquet: trade_history_110078.csv
# ✅ CSV→Parquet: trade_history_108637.csv
# ✅ CSV→Parquet: trade_history_4306.csv
# ✅ CSV→Parquet: trade_history_107504.csv
# ✅ CSV→Parquet: trade_history_118424.csv
# ✅ CSV→Parquet: trade_history_3469.csv
# ✅ CSV→Parquet: trade_history_10099.csv
# ✅ CSV→Parquet: trade_history_2763.csv
# ✅ CSV→Parquet: trade_history_11393.csv
# ✅ CSV→Parquet: trade_history_111372.csv
# ✅ CSV→Parquet: trade_history_108623.csv
# ✅ CSV→Parquet: trade_history_107510.csv
# ✅ CSV→Parquet: trade_history_129835.csv
# ✅ CSV→Parquet: trade_history_140883.csv
# ✅ CSV→Parquet: trade_history_12842.csv
# ✅ CSV→Parquet: trade_history_122960.csv
# ✅ CSV→Parquet: trade_history_8528.csv
# ✅ CSV→Parquet: trade_history_6505.csv
# ✅ CSV→Parquet: trade_history_22759.csv
# ✅ CSV→Parquet: trade_history_9636.csv
# ✅ CSV→Parquet: trade_history_115114.csv
# ✅ CSV→Parquet: trade_history_25036.csv
# ✅ CSV→Parquet: trade_history_102468.csv
# ✅ CSV→Parquet: trade_history_115672.csv
# ✅ CSV→Parquet: trade_history_9150.csv
# ✅ CSV→Parquet: trade_history_113203.csv
# ✅ CSV→Parquet: trade_history_100519.csv
# ✅ CSV→Parquet: trade_history_117065.csv
# ✅ CSV→Parquet: trade_history_27147.csv
# ✅ CSV→Parquet: trade_history_108145.csv
# ✅ CSV→Parquet: trade_history_128295.csv
# ✅ CSV→Parquet: trade_history_107276.csv
# ✅ CSV→Parquet: trade_history_111414.csv
# ✅ CSV→Parquet: trade_history_106168.csv
# ✅ CSV→Parquet: trade_history_10933.csv
# ✅ CSV→Parquet: trade_history_179964.csv
# ✅ CSV→Parquet: trade_history_2005.csv
# ✅ CSV→Parquet: trade_history_101607.csv
# ✅ CSV→Parquet: trade_history_5781.csv
# ✅ CSV→Parquet: trade_history_106183.csv
# ✅ CSV→Parquet: trade_history_110939.csv
# ✅ CSV→Parquet: trade_history_5959.csv
# ✅ CSV→Parquet: trade_history_101834.csv
# ✅ CSV→Parquet: trade_history_14566.csv
# ✅ CSV→Parquet: trade_history_115841.csv
# ✅ CSV→Parquet: trade_history_104794.csv
# ✅ CSV→Parquet: trade_history_25963.csv
# ✅ CSV→Parquet: trade_history_134657.csv
# ✅ CSV→Parquet: trade_history_114587.csv
# ✅ CSV→Parquet: trade_history_13209.csv
# ✅ CSV→Parquet: trade_history_222.csv
# ✅ CSV→Parquet: trade_history_135549.csv
# ✅ CSV→Parquet: trade_history_12117.csv
# ✅ CSV→Parquet: trade_history_15678.csv
# ✅ CSV→Parquet: trade_history_6288.csv
# ✅ CSV→Parquet: trade_history_145910.csv
# ✅ CSV→Parquet: trade_history_103945.csv
# ✅ CSV→Parquet: trade_history_24.csv
# ✅ CSV→Parquet: trade_history_102483.csv
# ✅ CSV→Parquet: trade_history_1281.csv
# ✅ CSV→Parquet: trade_history_122753.csv
# ✅ CSV→Parquet: trade_history_9805.csv
# ✅ CSV→Parquet: trade_history_14200.csv
# ✅ CSV→Parquet: trade_history_17709.csv
# ✅ CSV→Parquet: trade_history_110087.csv
# ✅ CSV→Parquet: trade_history_2950.csv
# ✅ CSV→Parquet: trade_history_10066.csv
# ✅ CSV→Parquet: trade_history_3496.csv
# ✅ CSV→Parquet: trade_history_11378.csv
# ✅ CSV→Parquet: trade_history_136726.csv
# ✅ CSV→Parquet: trade_history_2788.csv
# ✅ CSV→Parquet: trade_history_117930.csv
# ✅ CSV→Parquet: trade_history_119909.csv
# ✅ CSV→Parquet: trade_history_106829.csv
# ✅ CSV→Parquet: trade_history_10072.csv
# ✅ CSV→Parquet: trade_history_3482.csv
# ✅ CSV→Parquet: trade_history_100280.csv
# ✅ CSV→Parquet: trade_history_171479.csv
# ✅ CSV→Parquet: trade_history_117924.csv
# ✅ CSV→Parquet: trade_history_103951.csv
# ✅ CSV→Parquet: trade_history_125028.csv
# ✅ CSV→Parquet: trade_history_30.csv
# ✅ CSV→Parquet: trade_history_550.csv
# ✅ CSV→Parquet: trade_history_1295.csv
# ✅ CSV→Parquet: trade_history_25977.csv
# ✅ CSV→Parquet: trade_history_175179.csv
# ✅ CSV→Parquet: trade_history_104780.csv
# ✅ CSV→Parquet: trade_history_236.csv
# ✅ CSV→Parquet: trade_history_12103.csv
# ✅ CSV→Parquet: trade_history_106197.csv
# ✅ CSV→Parquet: trade_history_5795.csv
# ✅ CSV→Parquet: trade_history_116384.csv
# ✅ CSV→Parquet: trade_history_10714.csv
# ✅ CSV→Parquet: trade_history_101820.csv
# ✅ CSV→Parquet: trade_history_8299.csv
# ✅ CSV→Parquet: trade_history_155281.csv
# ✅ CSV→Parquet: trade_history_124478.csv
# ✅ CSV→Parquet: trade_history_13235.csv
# ✅ CSV→Parquet: trade_history_104970.csv
# ✅ CSV→Parquet: trade_history_25787.csv
# ✅ CSV→Parquet: trade_history_121500.csv
# ✅ CSV→Parquet: trade_history_11422.csv
# ✅ CSV→Parquet: trade_history_171337.csv
# ✅ CSV→Parquet: trade_history_17735.csv
# ✅ CSV→Parquet: trade_history_18406.csv
# ✅ CSV→Parquet: trade_history_11344.csv
# ✅ CSV→Parquet: trade_history_18.csv
# ✅ CSV→Parquet: trade_history_103979.csv
# ✅ CSV→Parquet: trade_history_7814.csv
# ✅ CSV→Parquet: trade_history_578.csv
# ✅ CSV→Parquet: trade_history_9839.csv
# ✅ CSV→Parquet: trade_history_22956.csv
# ✅ CSV→Parquet: trade_history_175637.csv
# ✅ CSV→Parquet: trade_history_132568.csv
# ✅ CSV→Parquet: trade_history_135207.csv
# ✅ CSV→Parquet: trade_history_13547.csv
# ✅ CSV→Parquet: trade_history_22942.csv
# ✅ CSV→Parquet: trade_history_133676.csv
# ✅ CSV→Parquet: trade_history_12881.csv
# ✅ CSV→Parquet: trade_history_14228.csv
# ✅ CSV→Parquet: trade_history_2978.csv
# ✅ CSV→Parquet: trade_history_127603.csv
# ✅ CSV→Parquet: trade_history_119935.csv
# ✅ CSV→Parquet: trade_history_128530.csv
# ✅ CSV→Parquet: trade_history_137410.csv
# ✅ CSV→Parquet: trade_history_106815.csv
# ✅ CSV→Parquet: trade_history_108838.csv
# ✅ CSV→Parquet: trade_history_11350.csv
# ✅ CSV→Parquet: trade_history_117918.csv
# ✅ CSV→Parquet: trade_history_11436.csv
# ✅ CSV→Parquet: trade_history_27184.csv
# ✅ CSV→Parquet: trade_history_5971.csv
# ✅ CSV→Parquet: trade_history_138045.csv
# ✅ CSV→Parquet: trade_history_10728.csv
# ✅ CSV→Parquet: trade_history_17047.csv
# ✅ CSV→Parquet: trade_history_18374.csv
# ✅ CSV→Parquet: trade_history_115869.csv
# ✅ CSV→Parquet: trade_history_155295.csv
# ✅ CSV→Parquet: trade_history_9193.csv
# ✅ CSV→Parquet: trade_history_125772.csv
# ✅ CSV→Parquet: trade_history_125835.csv
# ✅ CSV→Parquet: trade_history_114430.csv
# ✅ CSV→Parquet: trade_history_8312.csv
# ✅ CSV→Parquet: trade_history_102252.csv
# ✅ CSV→Parquet: trade_history_1450.csv
# ✅ CSV→Parquet: trade_history_395.csv
# ✅ CSV→Parquet: trade_history_140061.csv
# ✅ CSV→Parquet: trade_history_131698.csv
# ✅ CSV→Parquet: trade_history_111548.csv
# ✅ CSV→Parquet: trade_history_4528.csv
# ✅ CSV→Parquet: trade_history_110656.csv
# ✅ CSV→Parquet: trade_history_3247.csv
# ✅ CSV→Parquet: trade_history_3521.csv
# ✅ CSV→Parquet: trade_history_141419.csv
# ✅ CSV→Parquet: trade_history_5150.csv
# ✅ CSV→Parquet: trade_history_26463.csv
# ✅ CSV→Parquet: trade_history_1336.csv
# ✅ CSV→Parquet: trade_history_102534.csv
# ✅ CSV→Parquet: trade_history_144561.csv
# ✅ CSV→Parquet: trade_history_22605.csv
# ✅ CSV→Parquet: trade_history_6459.csv
# ✅ CSV→Parquet: trade_history_8474.csv
# ✅ CSV→Parquet: trade_history_104145.csv
# ✅ CSV→Parquet: trade_history_114356.csv
# ✅ CSV→Parquet: trade_history_102520.csv
# ✅ CSV→Parquet: trade_history_8460.csv
# ✅ CSV→Parquet: trade_history_122828.csv
# ✅ CSV→Parquet: trade_history_104151.csv
# ✅ CSV→Parquet: trade_history_24260.csv
# ✅ CSV→Parquet: trade_history_27769.csv
# ✅ CSV→Parquet: trade_history_149051.csv
# ✅ CSV→Parquet: trade_history_118578.csv
# ✅ CSV→Parquet: trade_history_3535.csv
# ✅ CSV→Parquet: trade_history_107458.csv
# ✅ CSV→Parquet: trade_history_110124.csv
# ✅ CSV→Parquet: trade_history_127788.csv
# ✅ CSV→Parquet: trade_history_117893.csv
# ✅ CSV→Parquet: trade_history_126496.csv
# ✅ CSV→Parquet: trade_history_116555.csv
# ✅ CSV→Parquet: trade_history_26477.csv
# ✅ CSV→Parquet: trade_history_150500.csv
# ✅ CSV→Parquet: trade_history_101029.csv
# ✅ CSV→Parquet: trade_history_119666.csv
# ✅ CSV→Parquet: trade_history_106020.csv
# ✅ CSV→Parquet: trade_history_3253.csv
# ✅ CSV→Parquet: trade_history_103158.csv
# ✅ CSV→Parquet: trade_history_15903.csv
# ✅ CSV→Parquet: trade_history_112055.csv
# ✅ CSV→Parquet: trade_history_9018.csv
# ✅ CSV→Parquet: trade_history_22177.csv
# ✅ CSV→Parquet: trade_history_381.csv
# ✅ CSV→Parquet: trade_history_1444.csv
# ✅ CSV→Parquet: trade_history_102246.csv
# ✅ CSV→Parquet: trade_history_25618.csv
# ✅ CSV→Parquet: trade_history_122196.csv
# ✅ CSV→Parquet: trade_history_2165.csv
# ✅ CSV→Parquet: trade_history_26339.csv
# ✅ CSV→Parquet: trade_history_11595.csv
# ✅ CSV→Parquet: trade_history_106008.csv
# ✅ CSV→Parquet: trade_history_10853.csv
# ✅ CSV→Parquet: trade_history_108025.csv
# ✅ CSV→Parquet: trade_history_107316.csv
# ✅ CSV→Parquet: trade_history_100479.csv
# ✅ CSV→Parquet: trade_history_151150.csv
# ✅ CSV→Parquet: trade_history_152459.csv
# ✅ CSV→Parquet: trade_history_13382.csv
# ✅ CSV→Parquet: trade_history_103170.csv
# ✅ CSV→Parquet: trade_history_6303.csv
# ✅ CSV→Parquet: trade_history_9030.csv
# ✅ CSV→Parquet: trade_history_25630.csv
# ✅ CSV→Parquet: trade_history_22639.csv
# ✅ CSV→Parquet: trade_history_12922.csv
# ✅ CSV→Parquet: trade_history_113405.csv
# ✅ CSV→Parquet: trade_history_8448.csv
# ✅ CSV→Parquet: trade_history_108743.csv
# ✅ CSV→Parquet: trade_history_119896.csv
# ✅ CSV→Parquet: trade_history_107470.csv
# ✅ CSV→Parquet: trade_history_177197.csv
# ✅ CSV→Parquet: trade_history_2603.csv
# ✅ CSV→Parquet: trade_history_27755.csv
# ✅ CSV→Parquet: trade_history_138694.csv
# ✅ CSV→Parquet: trade_history_108757.csv
# ✅ CSV→Parquet: trade_history_107464.csv
# ✅ CSV→Parquet: trade_history_109449.csv
# ✅ CSV→Parquet: trade_history_16588.csv
# ✅ CSV→Parquet: trade_history_5178.csv
# ✅ CSV→Parquet: trade_history_2617.csv
# ✅ CSV→Parquet: trade_history_116569.csv
# ✅ CSV→Parquet: trade_history_25142.csv
# ✅ CSV→Parquet: trade_history_105273.csv
# ✅ CSV→Parquet: trade_history_15081.csv
# ✅ CSV→Parquet: trade_history_9742.csv
# ✅ CSV→Parquet: trade_history_103602.csv
# ✅ CSV→Parquet: trade_history_103164.csv
# ✅ CSV→Parquet: trade_history_23255.csv
# ✅ CSV→Parquet: trade_history_113377.csv
# ✅ CSV→Parquet: trade_history_6317.csv
# ✅ CSV→Parquet: trade_history_12088.csv
# ✅ CSV→Parquet: trade_history_115706.csv
# ✅ CSV→Parquet: trade_history_1478.csv
# ✅ CSV→Parquet: trade_history_101773.csv
# ✅ CSV→Parquet: trade_history_11581.csv
# ✅ CSV→Parquet: trade_history_120965.csv
# ✅ CSV→Parquet: trade_history_140049.csv
# ✅ CSV→Parquet: trade_history_10847.csv
# ✅ CSV→Parquet: trade_history_108031.csv
# ✅ CSV→Parquet: trade_history_141357.csv
# ✅ CSV→Parquet: trade_history_118222.csv
# ✅ CSV→Parquet: trade_history_27033.csv
# ✅ CSV→Parquet: trade_history_110695.csv
# ✅ CSV→Parquet: trade_history_127039.csv
# ✅ CSV→Parquet: trade_history_10674.csv
# ✅ CSV→Parquet: trade_history_3284.csv
# ✅ CSV→Parquet: trade_history_19136.csv
# ✅ CSV→Parquet: trade_history_126327.csv
# ✅ CSV→Parquet: trade_history_356.csv
# ✅ CSV→Parquet: trade_history_102291.csv
# ✅ CSV→Parquet: trade_history_1493.csv
# ✅ CSV→Parquet: trade_history_104838.csv
# ✅ CSV→Parquet: trade_history_12063.csv
# ✅ CSV→Parquet: trade_history_134723.csv
# ✅ CSV→Parquet: trade_history_14412.csv
# ✅ CSV→Parquet: trade_history_25817.csv
# ✅ CSV→Parquet: trade_history_14374.csv
# ✅ CSV→Parquet: trade_history_104186.csv
# ✅ CSV→Parquet: trade_history_9971.csv
# ✅ CSV→Parquet: trade_history_430.csv
# ✅ CSV→Parquet: trade_history_103831.csv
# ✅ CSV→Parquet: trade_history_145864.csv
# ✅ CSV→Parquet: trade_history_117844.csv
# ✅ CSV→Parquet: trade_history_126441.csv
# ✅ CSV→Parquet: trade_history_16563.csv
# ✅ CSV→Parquet: trade_history_108964.csv
# ✅ CSV→Parquet: trade_history_106949.csv
# ✅ CSV→Parquet: trade_history_10112.csv
# ✅ CSV→Parquet: trade_history_2824.csv
# ✅ CSV→Parquet: trade_history_119869.csv
# ✅ CSV→Parquet: trade_history_106785.csv
# ✅ CSV→Parquet: trade_history_16577.csv
# ✅ CSV→Parquet: trade_history_108970.csv
# ✅ CSV→Parquet: trade_history_117688.csv
# ✅ CSV→Parquet: trade_history_10106.csv
# ✅ CSV→Parquet: trade_history_17669.csv
# ✅ CSV→Parquet: trade_history_2830.csv
# ✅ CSV→Parquet: trade_history_162217.csv
# ✅ CSV→Parquet: trade_history_14360.csv
# ✅ CSV→Parquet: trade_history_124242.csv
# ✅ CSV→Parquet: trade_history_104192.csv
# ✅ CSV→Parquet: trade_history_7790.csv
# ✅ CSV→Parquet: trade_history_112928.csv
# ✅ CSV→Parquet: trade_history_424.csv
# ✅ CSV→Parquet: trade_history_7948.csv
# ✅ CSV→Parquet: trade_history_103825.csv
# ✅ CSV→Parquet: trade_history_1487.csv
# ✅ CSV→Parquet: trade_history_102285.csv
# ✅ CSV→Parquet: trade_history_342.csv
# ✅ CSV→Parquet: trade_history_12077.csv
# ✅ CSV→Parquet: trade_history_13369.csv
# ✅ CSV→Parquet: trade_history_14406.csv
# ✅ CSV→Parquet: trade_history_113388.csv
# ✅ CSV→Parquet: trade_history_115921.csv
# ✅ CSV→Parquet: trade_history_147901.csv
# ✅ CSV→Parquet: trade_history_110681.csv
# ✅ CSV→Parquet: trade_history_161078.csv
# ✅ CSV→Parquet: trade_history_10660.csv
# ✅ CSV→Parquet: trade_history_5839.csv
# ✅ CSV→Parquet: trade_history_131897.csv
# ✅ CSV→Parquet: trade_history_120742.csv
# ✅ CSV→Parquet: trade_history_3290.csv
# ✅ CSV→Parquet: trade_history_129000.csv
# ✅ CSV→Parquet: trade_history_104804.csv
# ✅ CSV→Parquet: trade_history_13341.csv
# ✅ CSV→Parquet: trade_history_123263.csv
# ✅ CSV→Parquet: trade_history_141380.csv
# ✅ CSV→Parquet: trade_history_10648.csv
# ✅ CSV→Parquet: trade_history_110871.csv
# ✅ CSV→Parquet: trade_history_16239.csv
# ✅ CSV→Parquet: trade_history_11230.csv
# ✅ CSV→Parquet: trade_history_121312.csv
# ✅ CSV→Parquet: trade_history_27782.csv
# ✅ CSV→Parquet: trade_history_2818.csv
# ✅ CSV→Parquet: trade_history_119855.csv
# ✅ CSV→Parquet: trade_history_13427.csv
# ✅ CSV→Parquet: trade_history_12739.csv
# ✅ CSV→Parquet: trade_history_7960.csv
# ✅ CSV→Parquet: trade_history_132408.csv
# ✅ CSV→Parquet: trade_history_15056.csv
# ✅ CSV→Parquet: trade_history_9795.csv
# ✅ CSV→Parquet: trade_history_175757.csv
# ✅ CSV→Parquet: trade_history_13433.csv
# ✅ CSV→Parquet: trade_history_22836.csv
# ✅ CSV→Parquet: trade_history_112914.csv
# ✅ CSV→Parquet: trade_history_7974.csv
# ✅ CSV→Parquet: trade_history_418.csv
# ✅ CSV→Parquet: trade_history_9781.csv
# ✅ CSV→Parquet: trade_history_126469.csv
# ✅ CSV→Parquet: trade_history_19678.csv
# ✅ CSV→Parquet: trade_history_26488.csv
# ✅ CSV→Parquet: trade_history_129982.csv
# ✅ CSV→Parquet: trade_history_27796.csv
# ✅ CSV→Parquet: trade_history_108794.csv
# ✅ CSV→Parquet: trade_history_17655.csv
# ✅ CSV→Parquet: trade_history_18566.csv
# ✅ CSV→Parquet: trade_history_11542.csv
# ✅ CSV→Parquet: trade_history_22188.csv
# ✅ CSV→Parquet: trade_history_135415.csv
# ✅ CSV→Parquet: trade_history_13355.csv
# ✅ CSV→Parquet: trade_history_23296.csv
# ✅ CSV→Parquet: trade_history_103428.csv
# ✅ CSV→Parquet: trade_history_104347.csv
# ✅ CSV→Parquet: trade_history_8676.csv
# ✅ CSV→Parquet: trade_history_23719.csv
# ✅ CSV→Parquet: trade_history_9568.csv
# ✅ CSV→Parquet: trade_history_144763.csv
# ✅ CSV→Parquet: trade_history_102736.csv
# ✅ CSV→Parquet: trade_history_119470.csv
# ✅ CSV→Parquet: trade_history_107896.csv
# ✅ CSV→Parquet: trade_history_18957.csv
# ✅ CSV→Parquet: trade_history_109663.csv
# ✅ CSV→Parquet: trade_history_19491.csv
# ✅ CSV→Parquet: trade_history_106550.csv
# ✅ CSV→Parquet: trade_history_5352.csv
# ✅ CSV→Parquet: trade_history_126858.csv
# ✅ CSV→Parquet: trade_history_3723.csv
# ✅ CSV→Parquet: trade_history_118008.csv
# ✅ CSV→Parquet: trade_history_111992.csv
# ✅ CSV→Parquet: trade_history_3045.csv
# ✅ CSV→Parquet: trade_history_120597.csv
# ✅ CSV→Parquet: trade_history_11973.csv
# ✅ CSV→Parquet: trade_history_5434.csv
# ✅ CSV→Parquet: trade_history_101559.csv
# ✅ CSV→Parquet: trade_history_116025.csv
# ✅ CSV→Parquet: trade_history_26107.csv
# ✅ CSV→Parquet: trade_history_122380.csv
# ✅ CSV→Parquet: trade_history_197.csv
# ✅ CSV→Parquet: trade_history_1652.csv
# ✅ CSV→Parquet: trade_history_112243.csv
# ✅ CSV→Parquet: trade_history_22361.csv
# ✅ CSV→Parquet: trade_history_7223.csv
# ✅ CSV→Parquet: trade_history_104421.csv
# ✅ CSV→Parquet: trade_history_152667.csv
# ✅ CSV→Parquet: trade_history_115538.csv
# ✅ CSV→Parquet: trade_history_1646.csv
# ✅ CSV→Parquet: trade_history_183.csv
# ✅ CSV→Parquet: trade_history_6129.csv
# ✅ CSV→Parquet: trade_history_22375.csv
# ✅ CSV→Parquet: trade_history_112257.csv
# ✅ CSV→Parquet: trade_history_104435.csv
# ✅ CSV→Parquet: trade_history_7237.csv
# ✅ CSV→Parquet: trade_history_8104.csv
# ✅ CSV→Parquet: trade_history_24704.csv
# ✅ CSV→Parquet: trade_history_114626.csv
# ✅ CSV→Parquet: trade_history_100653.csv
# ✅ CSV→Parquet: trade_history_3051.csv
# ✅ CSV→Parquet: trade_history_111986.csv
# ✅ CSV→Parquet: trade_history_110440.csv
# ✅ CSV→Parquet: trade_history_130790.csv
# ✅ CSV→Parquet: trade_history_5420.csv
# ✅ CSV→Parquet: trade_history_26113.csv
# ✅ CSV→Parquet: trade_history_116031.csv
# ✅ CSV→Parquet: trade_history_119464.csv
# ✅ CSV→Parquet: trade_history_2429.csv
# ✅ CSV→Parquet: trade_history_18943.csv
# ✅ CSV→Parquet: trade_history_26675.csv
# ✅ CSV→Parquet: trade_history_116757.csv
# ✅ CSV→Parquet: trade_history_111038.csv
# ✅ CSV→Parquet: trade_history_126694.csv
# ✅ CSV→Parquet: trade_history_5346.csv
# ✅ CSV→Parquet: trade_history_108569.csv
# ✅ CSV→Parquet: trade_history_4058.csv
# ✅ CSV→Parquet: trade_history_3737.csv
# ✅ CSV→Parquet: trade_history_24062.csv
# ✅ CSV→Parquet: trade_history_8662.csv
# ✅ CSV→Parquet: trade_history_13816.csv
# ✅ CSV→Parquet: trade_history_112531.csv
# ✅ CSV→Parquet: trade_history_1120.csv
# ✅ CSV→Parquet: trade_history_144777.csv
# ✅ CSV→Parquet: trade_history_2401.csv
# ✅ CSV→Parquet: trade_history_101203.csv
# ✅ CSV→Parquet: trade_history_111010.csv
# ✅ CSV→Parquet: trade_history_4070.csv
# ✅ CSV→Parquet: trade_history_107672.csv
# ✅ CSV→Parquet: trade_history_26885.csv
# ✅ CSV→Parquet: trade_history_17480.csv
# ✅ CSV→Parquet: trade_history_138482.csv
# ✅ CSV→Parquet: trade_history_118752.csv
# ✅ CSV→Parquet: trade_history_114168.csv
# ✅ CSV→Parquet: trade_history_815.csv
# ✅ CSV→Parquet: trade_history_23725.csv
# ✅ CSV→Parquet: trade_history_113607.csv
# ✅ CSV→Parquet: trade_history_112519.csv
# ✅ CSV→Parquet: trade_history_9554.csv
# ✅ CSV→Parquet: trade_history_105065.csv
# ✅ CSV→Parquet: trade_history_1108.csv
# ✅ CSV→Parquet: trade_history_25354.csv
# ✅ CSV→Parquet: trade_history_115510.csv
# ✅ CSV→Parquet: trade_history_9232.csv
# ✅ CSV→Parquet: trade_history_105703.csv
# ✅ CSV→Parquet: trade_history_6101.csv
# ✅ CSV→Parquet: trade_history_23043.csv
# ✅ CSV→Parquet: trade_history_113161.csv
# ✅ CSV→Parquet: trade_history_27225.csv
# ✅ CSV→Parquet: trade_history_117307.csv
# ✅ CSV→Parquet: trade_history_3079.csv
# ✅ CSV→Parquet: trade_history_4716.csv
# ✅ CSV→Parquet: trade_history_108227.csv
# ✅ CSV→Parquet: trade_history_5408.csv
# ✅ CSV→Parquet: trade_history_101565.csv
# ✅ CSV→Parquet: trade_history_2367.csv
# ✅ CSV→Parquet: trade_history_27231.csv
# ✅ CSV→Parquet: trade_history_118020.csv
# ✅ CSV→Parquet: trade_history_4702.csv
# ✅ CSV→Parquet: trade_history_111762.csv
# ✅ CSV→Parquet: trade_history_11783.csv
# ✅ CSV→Parquet: trade_history_2373.csv
# ✅ CSV→Parquet: trade_history_101571.csv
# ✅ CSV→Parquet: trade_history_14823.csv
# ✅ CSV→Parquet: trade_history_102078.csv
# ✅ CSV→Parquet: trade_history_115504.csv
# ✅ CSV→Parquet: trade_history_9226.csv
# ✅ CSV→Parquet: trade_history_143742.csv
# ✅ CSV→Parquet: trade_history_105717.csv
# ✅ CSV→Parquet: trade_history_8138.csv
# ✅ CSV→Parquet: trade_history_104409.csv
# ✅ CSV→Parquet: trade_history_103366.csv
# ✅ CSV→Parquet: trade_history_24738.csv
# ✅ CSV→Parquet: trade_history_103400.csv
# ✅ CSV→Parquet: trade_history_801.csv
# ✅ CSV→Parquet: trade_history_23731.csv
# ✅ CSV→Parquet: trade_history_9540.csv
# ✅ CSV→Parquet: trade_history_105071.csv
# ✅ CSV→Parquet: trade_history_8886.csv
# ✅ CSV→Parquet: trade_history_25340.csv
# ✅ CSV→Parquet: trade_history_2415.csv
# ✅ CSV→Parquet: trade_history_111004.csv
# ✅ CSV→Parquet: trade_history_108555.csv
# ✅ CSV→Parquet: trade_history_17494.csv
# ✅ CSV→Parquet: trade_history_109893.csv
# ✅ CSV→Parquet: trade_history_130021.csv
# ✅ CSV→Parquet: trade_history_10310.csv
# ✅ CSV→Parquet: trade_history_120232.csv
# ✅ CSV→Parquet: trade_history_18994.csv
# ✅ CSV→Parquet: trade_history_116780.csv
# ✅ CSV→Parquet: trade_history_3938.csv
# ✅ CSV→Parquet: trade_history_118975.csv
# ✅ CSV→Parquet: trade_history_106593.csv
# ✅ CSV→Parquet: trade_history_115289.csv
# ✅ CSV→Parquet: trade_history_113820.csv
# ✅ CSV→Parquet: trade_history_632.csv
# ✅ CSV→Parquet: trade_history_13619.csv
# ✅ CSV→Parquet: trade_history_104384.csv
# ✅ CSV→Parquet: trade_history_7586.csv
# ✅ CSV→Parquet: trade_history_133528.csv
# ✅ CSV→Parquet: trade_history_14176.csv
# ✅ CSV→Parquet: trade_history_134521.csv
# ✅ CSV→Parquet: trade_history_1691.csv
# ✅ CSV→Parquet: trade_history_102093.csv
# ✅ CSV→Parquet: trade_history_154.csv
# ✅ CSV→Parquet: trade_history_112280.csv
# ✅ CSV→Parquet: trade_history_111789.csv
# ✅ CSV→Parquet: trade_history_126125.csv
# ✅ CSV→Parquet: trade_history_19334.csv
# ✅ CSV→Parquet: trade_history_2398.csv
# ✅ CSV→Parquet: trade_history_4931.csv
# ✅ CSV→Parquet: trade_history_11768.csv
# ✅ CSV→Parquet: trade_history_100684.csv
# ✅ CSV→Parquet: trade_history_10476.csv
# ✅ CSV→Parquet: trade_history_120554.csv
# ✅ CSV→Parquet: trade_history_110497.csv
# ✅ CSV→Parquet: trade_history_128108.csv
# ✅ CSV→Parquet: trade_history_16013.csv
# ✅ CSV→Parquet: trade_history_168538.csv
# ✅ CSV→Parquet: trade_history_4925.csv
# ✅ CSV→Parquet: trade_history_157910.csv
# ✅ CSV→Parquet: trade_history_100690.csv
# ✅ CSV→Parquet: trade_history_111945.csv
# ✅ CSV→Parquet: trade_history_3092.csv
# ✅ CSV→Parquet: trade_history_120540.csv
# ✅ CSV→Parquet: trade_history_10462.csv
# ✅ CSV→Parquet: trade_history_110483.csv
# ✅ CSV→Parquet: trade_history_14604.csv
# ✅ CSV→Parquet: trade_history_105930.csv
# ✅ CSV→Parquet: trade_history_103399.csv
# ✅ CSV→Parquet: trade_history_140.csv
# ✅ CSV→Parquet: trade_history_1685.csv
# ✅ CSV→Parquet: trade_history_112294.csv
# ✅ CSV→Parquet: trade_history_174677.csv
# ✅ CSV→Parquet: trade_history_626.csv
# ✅ CSV→Parquet: trade_history_23916.csv
# ✅ CSV→Parquet: trade_history_8879.csv
# ✅ CSV→Parquet: trade_history_6854.csv
# ✅ CSV→Parquet: trade_history_104390.csv
# ✅ CSV→Parquet: trade_history_102939.csv
# ✅ CSV→Parquet: trade_history_127549.csv
# ✅ CSV→Parquet: trade_history_176060.csv
# ✅ CSV→Parquet: trade_history_107699.csv
# ✅ CSV→Parquet: trade_history_130035.csv
# ✅ CSV→Parquet: trade_history_10304.csv
# ✅ CSV→Parquet: trade_history_107841.csv
# ✅ CSV→Parquet: trade_history_18980.csv
# ✅ CSV→Parquet: trade_history_19446.csv
# ✅ CSV→Parquet: trade_history_9597.csv
# ✅ CSV→Parquet: trade_history_125376.csv
# ✅ CSV→Parquet: trade_history_135165.csv
# ✅ CSV→Parquet: trade_history_25397.csv
# ✅ CSV→Parquet: trade_history_13625.csv
# ✅ CSV→Parquet: trade_history_102911.csv
# ✅ CSV→Parquet: trade_history_8689.csv
# ✅ CSV→Parquet: trade_history_26846.csv
# ✅ CSV→Parquet: trade_history_17443.csv
# ✅ CSV→Parquet: trade_history_118791.csv
# ✅ CSV→Parquet: trade_history_109844.csv
# ✅ CSV→Parquet: trade_history_11032.csv
# ✅ CSV→Parquet: trade_history_3904.csv
# ✅ CSV→Parquet: trade_history_100860.csv
# ✅ CSV→Parquet: trade_history_11754.csv
# ✅ CSV→Parquet: trade_history_141182.csv
# ✅ CSV→Parquet: trade_history_127207.csv
# ✅ CSV→Parquet: trade_history_17325.csv
# ✅ CSV→Parquet: trade_history_1875.csv
# ✅ CSV→Parquet: trade_history_13143.csv
# ✅ CSV→Parquet: trade_history_168.csv
# ✅ CSV→Parquet: trade_history_24937.csv
# ✅ CSV→Parquet: trade_history_114815.csv
# ✅ CSV→Parquet: trade_history_23094.csv
# ✅ CSV→Parquet: trade_history_1861.csv
# ✅ CSV→Parquet: trade_history_14638.csv
# ✅ CSV→Parquet: trade_history_133266.csv
# ✅ CSV→Parquet: trade_history_134509.csv
# ✅ CSV→Parquet: trade_history_143959.csv
# ✅ CSV→Parquet: trade_history_143781.csv
# ✅ CSV→Parquet: trade_history_160158.csv
# ✅ CSV→Parquet: trade_history_4919.csv
# ✅ CSV→Parquet: trade_history_111979.csv
# ✅ CSV→Parquet: trade_history_11998.csv
# ✅ CSV→Parquet: trade_history_17331.csv
# ✅ CSV→Parquet: trade_history_128646.csv
# ✅ CSV→Parquet: trade_history_147281.csv
# ✅ CSV→Parquet: trade_history_16749.csv
# ✅ CSV→Parquet: trade_history_3910.csv
# ✅ CSV→Parquet: trade_history_9583.csv
# ✅ CSV→Parquet: trade_history_8845.csv
# ✅ CSV→Parquet: trade_history_123713.csv
# ✅ CSV→Parquet: trade_history_102905.csv
# ✅ CSV→Parquet: trade_history_17330.csv
# ✅ CSV→Parquet: trade_history_18003.csv
# ✅ CSV→Parquet: trade_history_4918.csv
# ✅ CSV→Parquet: trade_history_100875.csv
# ✅ CSV→Parquet: trade_history_24922.csv
# ✅ CSV→Parquet: trade_history_143780.csv
# ✅ CSV→Parquet: trade_history_152855.csv
# ✅ CSV→Parquet: trade_history_13156.csv
# ✅ CSV→Parquet: trade_history_134508.csv
# ✅ CSV→Parquet: trade_history_14639.csv
# ✅ CSV→Parquet: trade_history_1860.csv
# ✅ CSV→Parquet: trade_history_102904.csv
# ✅ CSV→Parquet: trade_history_123712.csv
# ✅ CSV→Parquet: trade_history_8844.csv
# ✅ CSV→Parquet: trade_history_9582.csv
# ✅ CSV→Parquet: trade_history_3911.csv
# ✅ CSV→Parquet: trade_history_11027.csv
# ✅ CSV→Parquet: trade_history_109851.csv
# ✅ CSV→Parquet: trade_history_10339.csv
# ✅ CSV→Parquet: trade_history_17456.csv
# ✅ CSV→Parquet: trade_history_127574.csv
# ✅ CSV→Parquet: trade_history_116971.csv
# ✅ CSV→Parquet: trade_history_26853.csv
# ✅ CSV→Parquet: trade_history_3905.csv
# ✅ CSV→Parquet: trade_history_118948.csv
# ✅ CSV→Parquet: trade_history_168277.csv
# ✅ CSV→Parquet: trade_history_11033.csv
# ✅ CSV→Parquet: trade_history_27581.csv
# ✅ CSV→Parquet: trade_history_108583.csv
# ✅ CSV→Parquet: trade_history_17442.csv
# ✅ CSV→Parquet: trade_history_102910.csv
# ✅ CSV→Parquet: trade_history_8688.csv
# ✅ CSV→Parquet: trade_history_24088.csv
# ✅ CSV→Parquet: trade_history_13624.csv
# ✅ CSV→Parquet: trade_history_122418.csv
# ✅ CSV→Parquet: trade_history_8850.csv
# ✅ CSV→Parquet: trade_history_24936.csv
# ✅ CSV→Parquet: trade_history_114814.csv
# ✅ CSV→Parquet: trade_history_125411.csv
# ✅ CSV→Parquet: trade_history_169.csv
# ✅ CSV→Parquet: trade_history_13142.csv
# ✅ CSV→Parquet: trade_history_1874.csv
# ✅ CSV→Parquet: trade_history_23081.csv
# ✅ CSV→Parquet: trade_history_17324.csv
# ✅ CSV→Parquet: trade_history_141183.csv
# ✅ CSV→Parquet: trade_history_128135.csv
# ✅ CSV→Parquet: trade_history_157939.csv
# ✅ CSV→Parquet: trade_history_19309.csv
# ✅ CSV→Parquet: trade_history_141.csv
# ✅ CSV→Parquet: trade_history_1684.csv
# ✅ CSV→Parquet: trade_history_103398.csv
# ✅ CSV→Parquet: trade_history_105931.csv
# ✅ CSV→Parquet: trade_history_14605.csv
# ✅ CSV→Parquet: trade_history_110482.csv
# ✅ CSV→Parquet: trade_history_10463.csv
# ✅ CSV→Parquet: trade_history_3093.csv
# ✅ CSV→Parquet: trade_history_100691.csv
# ✅ CSV→Parquet: trade_history_126130.csv
# ✅ CSV→Parquet: trade_history_100849.csv
# ✅ CSV→Parquet: trade_history_19447.csv
# ✅ CSV→Parquet: trade_history_129565.csv
# ✅ CSV→Parquet: trade_history_137983.csv
# ✅ CSV→Parquet: trade_history_107840.csv
# ✅ CSV→Parquet: trade_history_18981.csv
# ✅ CSV→Parquet: trade_history_120227.csv
# ✅ CSV→Parquet: trade_history_107698.csv
# ✅ CSV→Parquet: trade_history_150918.csv
# ✅ CSV→Parquet: trade_history_102938.csv
# ✅ CSV→Parquet: trade_history_14163.csv
# ✅ CSV→Parquet: trade_history_6855.csv
# ✅ CSV→Parquet: trade_history_114182.csv
# ✅ CSV→Parquet: trade_history_8878.csv
# ✅ CSV→Parquet: trade_history_627.csv
# ✅ CSV→Parquet: trade_history_113835.csv
# ✅ CSV→Parquet: trade_history_122430.csv
# ✅ CSV→Parquet: trade_history_14177.csv
# ✅ CSV→Parquet: trade_history_104385.csv
# ✅ CSV→Parquet: trade_history_13618.csv
# ✅ CSV→Parquet: trade_history_633.csv
# ✅ CSV→Parquet: trade_history_115288.csv
# ✅ CSV→Parquet: trade_history_122424.csv
# ✅ CSV→Parquet: trade_history_174662.csv
# ✅ CSV→Parquet: trade_history_6699.csv
# ✅ CSV→Parquet: trade_history_3939.csv
# ✅ CSV→Parquet: trade_history_118974.csv
# ✅ CSV→Parquet: trade_history_126642.csv
# ✅ CSV→Parquet: trade_history_18995.csv
# ✅ CSV→Parquet: trade_history_107854.csv
# ✅ CSV→Parquet: trade_history_10311.csv
# ✅ CSV→Parquet: trade_history_110496.csv
# ✅ CSV→Parquet: trade_history_100685.csv
# ✅ CSV→Parquet: trade_history_11769.csv
# ✅ CSV→Parquet: trade_history_4930.csv
# ✅ CSV→Parquet: trade_history_2399.csv
# ✅ CSV→Parquet: trade_history_19335.csv
# ✅ CSV→Parquet: trade_history_126124.csv
# ✅ CSV→Parquet: trade_history_112281.csv
# ✅ CSV→Parquet: trade_history_1690.csv
# ✅ CSV→Parquet: trade_history_155.csv
# ✅ CSV→Parquet: trade_history_105925.csv
# ✅ CSV→Parquet: trade_history_1848.csv
# ✅ CSV→Parquet: trade_history_14611.csv
# ✅ CSV→Parquet: trade_history_13195.csv
# ✅ CSV→Parquet: trade_history_104408.csv
# ✅ CSV→Parquet: trade_history_8139.csv
# ✅ CSV→Parquet: trade_history_105716.csv
# ✅ CSV→Parquet: trade_history_6114.csv
# ✅ CSV→Parquet: trade_history_22348.csv
# ✅ CSV→Parquet: trade_history_115505.csv
# ✅ CSV→Parquet: trade_history_102079.csv
# ✅ CSV→Parquet: trade_history_173680.csv
# ✅ CSV→Parquet: trade_history_101570.csv
# ✅ CSV→Parquet: trade_history_2372.csv
# ✅ CSV→Parquet: trade_history_11782.csv
# ✅ CSV→Parquet: trade_history_107101.csv
# ✅ CSV→Parquet: trade_history_118021.csv
# ✅ CSV→Parquet: trade_history_117312.csv
# ✅ CSV→Parquet: trade_history_27230.csv
# ✅ CSV→Parquet: trade_history_100108.csv
# ✅ CSV→Parquet: trade_history_118747.csv
# ✅ CSV→Parquet: trade_history_109892.csv
# ✅ CSV→Parquet: trade_history_117474.csv
# ✅ CSV→Parquet: trade_history_27556.csv
# ✅ CSV→Parquet: trade_history_17495.csv
# ✅ CSV→Parquet: trade_history_4065.csv
# ✅ CSV→Parquet: trade_history_119459.csv
# ✅ CSV→Parquet: trade_history_2414.csv
# ✅ CSV→Parquet: trade_history_115263.csv
# ✅ CSV→Parquet: trade_history_25341.csv
# ✅ CSV→Parquet: trade_history_105070.csv
# ✅ CSV→Parquet: trade_history_113612.csv
# ✅ CSV→Parquet: trade_history_800.csv
# ✅ CSV→Parquet: trade_history_103401.csv
# ✅ CSV→Parquet: trade_history_25355.csv
# ✅ CSV→Parquet: trade_history_115277.csv
# ✅ CSV→Parquet: trade_history_8893.csv
# ✅ CSV→Parquet: trade_history_1109.csv
# ✅ CSV→Parquet: trade_history_105064.csv
# ✅ CSV→Parquet: trade_history_6666.csv
# ✅ CSV→Parquet: trade_history_112518.csv
# ✅ CSV→Parquet: trade_history_814.csv
# ✅ CSV→Parquet: trade_history_144986.csv
# ✅ CSV→Parquet: trade_history_14188.csv
# ✅ CSV→Parquet: trade_history_16947.csv
# ✅ CSV→Parquet: trade_history_17481.csv
# ✅ CSV→Parquet: trade_history_101202.csv
# ✅ CSV→Parquet: trade_history_2400.csv
# ✅ CSV→Parquet: trade_history_2366.csv
# ✅ CSV→Parquet: trade_history_116018.csv
# ✅ CSV→Parquet: trade_history_130961.csv
# ✅ CSV→Parquet: trade_history_110469.csv
# ✅ CSV→Parquet: trade_history_108226.csv
# ✅ CSV→Parquet: trade_history_4717.csv
# ✅ CSV→Parquet: trade_history_3078.csv
# ✅ CSV→Parquet: trade_history_117306.csv
# ✅ CSV→Parquet: trade_history_10488.csv
# ✅ CSV→Parquet: trade_history_13181.csv
# ✅ CSV→Parquet: trade_history_23042.csv
# ✅ CSV→Parquet: trade_history_105702.csv
# ✅ CSV→Parquet: trade_history_9233.csv
# ✅ CSV→Parquet: trade_history_115511.csv
# ✅ CSV→Parquet: trade_history_26112.csv
# ✅ CSV→Parquet: trade_history_5421.csv
# ✅ CSV→Parquet: trade_history_11966.csv
# ✅ CSV→Parquet: trade_history_100652.csv
# ✅ CSV→Parquet: trade_history_24705.csv
# ✅ CSV→Parquet: trade_history_114627.csv
# ✅ CSV→Parquet: trade_history_113148.csv
# ✅ CSV→Parquet: trade_history_8105.csv
# ✅ CSV→Parquet: trade_history_112256.csv
# ✅ CSV→Parquet: trade_history_132186.csv
# ✅ CSV→Parquet: trade_history_6128.csv
# ✅ CSV→Parquet: trade_history_115539.csv
# ✅ CSV→Parquet: trade_history_102723.csv
# ✅ CSV→Parquet: trade_history_1121.csv
# ✅ CSV→Parquet: trade_history_112530.csv
# ✅ CSV→Parquet: trade_history_13817.csv
# ✅ CSV→Parquet: trade_history_8663.csv
# ✅ CSV→Parquet: trade_history_104352.csv
# ✅ CSV→Parquet: trade_history_7550.csv
# ✅ CSV→Parquet: trade_history_3736.csv
# ✅ CSV→Parquet: trade_history_108568.csv
# ✅ CSV→Parquet: trade_history_106545.csv
# ✅ CSV→Parquet: trade_history_5347.csv
# ✅ CSV→Parquet: trade_history_109676.csv
# ✅ CSV→Parquet: trade_history_26674.csv
# ✅ CSV→Parquet: trade_history_18942.csv
# ✅ CSV→Parquet: trade_history_116756.csv
# ✅ CSV→Parquet: trade_history_2428.csv
# ✅ CSV→Parquet: trade_history_3722.csv
# ✅ CSV→Parquet: trade_history_156366.csv
# ✅ CSV→Parquet: trade_history_19490.csv
# ✅ CSV→Parquet: trade_history_106551.csv
# ✅ CSV→Parquet: trade_history_109662.csv
# ✅ CSV→Parquet: trade_history_107897.csv
# ✅ CSV→Parquet: trade_history_26660.csv
# ✅ CSV→Parquet: trade_history_144762.csv
# ✅ CSV→Parquet: trade_history_1135.csv
# ✅ CSV→Parquet: trade_history_102737.csv
# ✅ CSV→Parquet: trade_history_25369.csv
# ✅ CSV→Parquet: trade_history_125388.csv
# ✅ CSV→Parquet: trade_history_9569.csv
# ✅ CSV→Parquet: trade_history_22406.csv
# ✅ CSV→Parquet: trade_history_13803.csv
# ✅ CSV→Parquet: trade_history_828.csv
# ✅ CSV→Parquet: trade_history_23718.csv
# ✅ CSV→Parquet: trade_history_8677.csv
# ✅ CSV→Parquet: trade_history_7544.csv
# ✅ CSV→Parquet: trade_history_103429.csv
# ✅ CSV→Parquet: trade_history_8111.csv
# ✅ CSV→Parquet: trade_history_135825.csv
# ✅ CSV→Parquet: trade_history_7222.csv
# ✅ CSV→Parquet: trade_history_112242.csv
# ✅ CSV→Parquet: trade_history_180720.csv
# ✅ CSV→Parquet: trade_history_22360.csv
# ✅ CSV→Parquet: trade_history_196.csv
# ✅ CSV→Parquet: trade_history_102051.csv
# ✅ CSV→Parquet: trade_history_1653.csv
# ✅ CSV→Parquet: trade_history_116024.csv
# ✅ CSV→Parquet: trade_history_26106.csv
# ✅ CSV→Parquet: trade_history_121688.csv
# ✅ CSV→Parquet: trade_history_101558.csv
# ✅ CSV→Parquet: trade_history_119317.csv
# ✅ CSV→Parquet: trade_history_106237.csv
# ✅ CSV→Parquet: trade_history_5435.csv
# ✅ CSV→Parquet: trade_history_11972.csv
# ✅ CSV→Parquet: trade_history_110455.csv
# ✅ CSV→Parquet: trade_history_27218.csv
# ✅ CSV→Parquet: trade_history_100646.csv
# ✅ CSV→Parquet: trade_history_18567.csv
# ✅ CSV→Parquet: trade_history_17654.csv
# ✅ CSV→Parquet: trade_history_106960.csv
# ✅ CSV→Parquet: trade_history_27797.csv
# ✅ CSV→Parquet: trade_history_121307.csv
# ✅ CSV→Parquet: trade_history_26489.csv
# ✅ CSV→Parquet: trade_history_11225.csv
# ✅ CSV→Parquet: trade_history_19679.csv
# ✅ CSV→Parquet: trade_history_125161.csv
# ✅ CSV→Parquet: trade_history_15043.csv
# ✅ CSV→Parquet: trade_history_419.csv
# ✅ CSV→Parquet: trade_history_25180.csv
# ✅ CSV→Parquet: trade_history_22837.csv
# ✅ CSV→Parquet: trade_history_9958.csv
# ✅ CSV→Parquet: trade_history_112915.csv
# ✅ CSV→Parquet: trade_history_13432.csv
# ✅ CSV→Parquet: trade_history_13354.csv
# ✅ CSV→Parquet: trade_history_104811.csv
# ✅ CSV→Parquet: trade_history_122168.csv
# ✅ CSV→Parquet: trade_history_22189.csv
# ✅ CSV→Parquet: trade_history_10885.csv
# ✅ CSV→Parquet: trade_history_11543.csv
# ✅ CSV→Parquet: trade_history_5804.csv
# ✅ CSV→Parquet: trade_history_128323.csv
# ✅ CSV→Parquet: trade_history_131666.csv
# ✅ CSV→Parquet: trade_history_10891.csv
# ✅ CSV→Parquet: trade_history_16238.csv
# ✅ CSV→Parquet: trade_history_10649.csv
# ✅ CSV→Parquet: trade_history_158808.csv
# ✅ CSV→Parquet: trade_history_141381.csv
# ✅ CSV→Parquet: trade_history_130578.csv
# ✅ CSV→Parquet: trade_history_18215.csv
# ✅ CSV→Parquet: trade_history_127004.csv
# ✅ CSV→Parquet: trade_history_23283.csv
# ✅ CSV→Parquet: trade_history_13340.csv
# ✅ CSV→Parquet: trade_history_104805.csv
# ✅ CSV→Parquet: trade_history_15731.csv
# ✅ CSV→Parquet: trade_history_9794.csv
# ✅ CSV→Parquet: trade_history_25194.csv
# ✅ CSV→Parquet: trade_history_7961.csv
# ✅ CSV→Parquet: trade_history_22823.csv
# ✅ CSV→Parquet: trade_history_14349.csv
# ✅ CSV→Parquet: trade_history_119854.csv
# ✅ CSV→Parquet: trade_history_138642.csv
# ✅ CSV→Parquet: trade_history_106974.csv
# ✅ CSV→Parquet: trade_history_118592.csv
# ✅ CSV→Parquet: trade_history_11231.csv
# ✅ CSV→Parquet: trade_history_108959.csv
# ✅ CSV→Parquet: trade_history_117879.csv
# ✅ CSV→Parquet: trade_history_145871.csv
# ✅ CSV→Parquet: trade_history_122632.csv
# ✅ CSV→Parquet: trade_history_425.csv
# ✅ CSV→Parquet: trade_history_114380.csv
# ✅ CSV→Parquet: trade_history_9964.csv
# ✅ CSV→Parquet: trade_history_7791.csv
# ✅ CSV→Parquet: trade_history_104193.csv
# ✅ CSV→Parquet: trade_history_14361.csv
# ✅ CSV→Parquet: trade_history_2831.csv
# ✅ CSV→Parquet: trade_history_17668.csv
# ✅ CSV→Parquet: trade_history_10107.csv
# ✅ CSV→Parquet: trade_history_140909.csv
# ✅ CSV→Parquet: trade_history_120025.csv
# ✅ CSV→Parquet: trade_history_108971.csv
# ✅ CSV→Parquet: trade_history_11219.csv
# ✅ CSV→Parquet: trade_history_5186.csv
# ✅ CSV→Parquet: trade_history_129767.csv
# ✅ CSV→Parquet: trade_history_106784.csv
# ✅ CSV→Parquet: trade_history_16210.csv
# ✅ CSV→Parquet: trade_history_19123.csv
# ✅ CSV→Parquet: trade_history_110858.csv
# ✅ CSV→Parquet: trade_history_100493.csv
# ✅ CSV→Parquet: trade_history_3291.csv
# ✅ CSV→Parquet: trade_history_10661.csv
# ✅ CSV→Parquet: trade_history_120743.csv
# ✅ CSV→Parquet: trade_history_110680.csv
# ✅ CSV→Parquet: trade_history_25802.csv
# ✅ CSV→Parquet: trade_history_153975.csv
# ✅ CSV→Parquet: trade_history_113389.csv
# ...
# ✅ CSV→Parquet: trade_history_120161.csv
# ✅ CSV→Parquet: trade_history_118398.csv
# ✅ CSV→Parquet: trade_history_10725.csv
# ✅ CSV→Parquet: trade_history_27189.csv
# ✅ CSV→Parquet: trade_history_176441.csv
# ✅ CSV→Parquet: trade_history_19067.csv
# ✅ CSV→Parquet: trade_history_119086.csv
# ✅ CSV→Parquet: trade_history_26297.csv
# ✅ CSV→Parquet: trade_history_121519.csv
# ✅ CSV→Parquet: trade_history_173539.csv
# ✅ CSV→Parquet: trade_history_207.csv
# ✅ CSV→Parquet: trade_history_115864.csv
# ✅ CSV→Parquet: trade_history_14543.csv
# ✅ CSV→Parquet: trade_history_8280.csv
# ✅ CSV→Parquet: trade_history_15885.csv
# ✅ CSV→Parquet: trade_history_137353.csv
# ✅ CSV→Parquet: trade_history_107290.csv
# ✅ CSV→Parquet: trade_history_127140.csv
# ✅ CSV→Parquet: trade_history_11413.csv
# ✅ CSV→Parquet: trade_history_110934.csv
# ✅ CSV→Parquet: trade_history_135544.csv
# ✅ CSV→Parquet: trade_history_122038.csv
# ✅ CSV→Parquet: trade_history_115694.csv
# ✅ CSV→Parquet: trade_history_125757.csv
# ✅ CSV→Parquet: trade_history_105487.csv
# ✅ CSV→Parquet: trade_history_6285.csv
# ✅ CSV→Parquet: trade_history_112845.csv
# ✅ CSV→Parquet: trade_history_9808.csv
# ✅ CSV→Parquet: trade_history_13562.csv
# ✅ CSV→Parquet: trade_history_113583.csv
# ✅ CSV→Parquet: trade_history_103948.csv
# ✅ CSV→Parquet: trade_history_29.csv
# ✅ CSV→Parquet: trade_history_549.csv
# ✅ CSV→Parquet: trade_history_11375.csv
# ✅ CSV→Parquet: trade_history_2785.csv
# ✅ CSV→Parquet: trade_history_111394.csv
# ✅ CSV→Parquet: trade_history_128515.csv
# ✅ CSV→Parquet: trade_history_119910.csv
# ✅ CSV→Parquet: trade_history_140865.csv
# ✅ CSV→Parquet: trade_history_138706.csv
# ✅ CSV→Parquet: trade_history_100299.csv
# ✅ CSV→Parquet: trade_history_101193.csv
# ✅ CSV→Parquet: trade_history_2791.csv
# ✅ CSV→Parquet: trade_history_119904.csv
# ✅ CSV→Parquet: trade_history_2949.csv
# ✅ CSV→Parquet: trade_history_106824.csv
# ✅ CSV→Parquet: trade_history_140871.csv
# ✅ CSV→Parquet: trade_history_22973.csv
# ✅ CSV→Parquet: trade_history_112851.csv
# ✅ CSV→Parquet: trade_history_13576.csv
# ✅ CSV→Parquet: trade_history_14219.csv
# ✅ CSV→Parquet: trade_history_113597.csv
# ✅ CSV→Parquet: trade_history_125025.csv
# ✅ CSV→Parquet: trade_history_145909.csv
# ✅ CSV→Parquet: trade_history_1298.csv
# ✅ CSV→Parquet: trade_history_135550.csv
# ✅ CSV→Parquet: trade_history_104955.csv
# ✅ CSV→Parquet: trade_history_15661.csv
# ✅ CSV→Parquet: trade_history_105493.csv
# ✅ CSV→Parquet: trade_history_13210.csv
# ✅ CSV→Parquet: trade_history_117097.csv
# ✅ CSV→Parquet: trade_history_10719.csv
# ✅ CSV→Parquet: trade_history_18345.csv
# ✅ CSV→Parquet: trade_history_107284.csv
# ✅ CSV→Parquet: trade_history_5798.csv
# ✅ CSV→Parquet: trade_history_121525.csv
# ✅ CSV→Parquet: trade_history_11407.csv
# ✅ CSV→Parquet: trade_history_109242.csv
# ✅ CSV→Parquet: trade_history_5773.csv
# ✅ CSV→Parquet: trade_history_106171.csv
# ✅ CSV→Parquet: trade_history_120808.csv
# ✅ CSV→Parquet: trade_history_150337.csv
# ✅ CSV→Parquet: trade_history_26240.csv
# ✅ CSV→Parquet: trade_history_100500.csv
# ✅ CSV→Parquet: trade_history_110713.csv
# ✅ CSV→Parquet: trade_history_7164.csv
# ✅ CSV→Parquet: trade_history_14594.csv
# ✅ CSV→Parquet: trade_history_114575.csv
# ✅ CSV→Parquet: trade_history_25749.csv
# ✅ CSV→Parquet: trade_history_105478.csv
# ✅ CSV→Parquet: trade_history_9149.csv
# ✅ CSV→Parquet: trade_history_12683.csv
# ✅ CSV→Parquet: trade_history_102471.csv
# ✅ CSV→Parquet: trade_history_1273.csv
# ✅ CSV→Parquet: trade_history_24331.csv
# ✅ CSV→Parquet: trade_history_104000.csv
# ✅ CSV→Parquet: trade_history_8531.csv
# ✅ CSV→Parquet: trade_history_107509.csv
# ✅ CSV→Parquet: trade_history_3464.csv
# ✅ CSV→Parquet: trade_history_27638.csv
# ✅ CSV→Parquet: trade_history_119737.csv
# ✅ CSV→Parquet: trade_history_26526.csv
# ✅ CSV→Parquet: trade_history_116404.csv
# ✅ CSV→Parquet: trade_history_109524.csv
# ✅ CSV→Parquet: trade_history_106617.csv
# ✅ CSV→Parquet: trade_history_5015.csv
# ✅ CSV→Parquet: trade_history_3470.csv
# ✅ CSV→Parquet: trade_history_10080.csv
# ✅ CSV→Parquet: trade_history_119723.csv
# ✅ CSV→Parquet: trade_history_127815.csv
# ✅ CSV→Parquet: trade_history_26532.csv
# ✅ CSV→Parquet: trade_history_109530.csv
# ✅ CSV→Parquet: trade_history_106603.csv
# ✅ CSV→Parquet: trade_history_6508.csv
# ✅ CSV→Parquet: trade_history_22754.csv
# ✅ CSV→Parquet: trade_history_115119.csv
# ✅ CSV→Parquet: trade_history_1267.csv
# ✅ CSV→Parquet: trade_history_102465.csv
# ✅ CSV→Parquet: trade_history_13589.csv
# ✅ CSV→Parquet: trade_history_104014.csv
# ✅ CSV→Parquet: trade_history_8525.csv
# ✅ CSV→Parquet: trade_history_104772.csv
# ✅ CSV→Parquet: trade_history_7170.csv
# ✅ CSV→Parquet: trade_history_8243.csv
# ✅ CSV→Parquet: trade_history_14580.csv
# ✅ CSV→Parquet: trade_history_24443.csv
# ✅ CSV→Parquet: trade_history_152534.csv
# ✅ CSV→Parquet: trade_history_125964.csv
# ✅ CSV→Parquet: trade_history_145048.csv
# ✅ CSV→Parquet: trade_history_1501.csv
# ✅ CSV→Parquet: trade_history_112110.csv
# ✅ CSV→Parquet: trade_history_154145.csv
# ✅ CSV→Parquet: trade_history_106165.csv
# ✅ CSV→Parquet: trade_history_5767.csv
# ✅ CSV→Parquet: trade_history_2008.csv
# ✅ CSV→Parquet: trade_history_150323.csv
# ✅ CSV→Parquet: trade_history_100514.csv
# ✅ CSV→Parquet: trade_history_3316.csv
# ✅ CSV→Parquet: trade_history_108148.csv
# ✅ CSV→Parquet: trade_history_4479.csv
# ✅ CSV→Parquet: trade_history_128298.csv
# ✅ CSV→Parquet: trade_history_113226.csv
# ✅ CSV→Parquet: trade_history_7158.csv
# ✅ CSV→Parquet: trade_history_103035.csv
# ✅ CSV→Parquet: trade_history_114549.csv
# ✅ CSV→Parquet: trade_history_1529.csv
# ✅ CSV→Parquet: trade_history_104982.csv
# ✅ CSV→Parquet: trade_history_115657.csv
# ✅ CSV→Parquet: trade_history_25775.csv
# ✅ CSV→Parquet: trade_history_153602.csv
# ✅ CSV→Parquet: trade_history_9175.csv
# ✅ CSV→Parquet: trade_history_112138.csv
# ✅ CSV→Parquet: trade_history_6246.csv
# ✅ CSV→Parquet: trade_history_10916.csv
# ✅ CSV→Parquet: trade_history_148544.csv
# ✅ CSV→Parquet: trade_history_147677.csv
# ✅ CSV→Parquet: trade_history_5997.csv
# ✅ CSV→Parquet: trade_history_117040.csv
# ✅ CSV→Parquet: trade_history_27162.csv
# ✅ CSV→Parquet: trade_history_107253.csv
# ✅ CSV→Parquet: trade_history_108160.csv
# ✅ CSV→Parquet: trade_history_127183.csv
# ✅ CSV→Parquet: trade_history_4337.csv
# ✅ CSV→Parquet: trade_history_107535.csv
# ✅ CSV→Parquet: trade_history_108606.csv
# ✅ CSV→Parquet: trade_history_110049.csv
# ✅ CSV→Parquet: trade_history_27604.csv
# ✅ CSV→Parquet: trade_history_116438.csv
# ✅ CSV→Parquet: trade_history_2746.csv
# ✅ CSV→Parquet: trade_history_101144.csv
# ✅ CSV→Parquet: trade_history_5029.csv
# ✅ CSV→Parquet: trade_history_105322.csv
# ✅ CSV→Parquet: trade_history_25013.csv
# ✅ CSV→Parquet: trade_history_112886.csv
# ✅ CSV→Parquet: trade_history_103753.csv
# ✅ CSV→Parquet: trade_history_123483.csv
# ✅ CSV→Parquet: trade_history_12867.csv
# ✅ CSV→Parquet: trade_history_9607.csv
# ✅ CSV→Parquet: trade_history_22768.csv
# ✅ CSV→Parquet: trade_history_6534.csv
# ✅ CSV→Parquet: trade_history_143363.csv
# ✅ CSV→Parquet: trade_history_102459.csv
# ✅ CSV→Parquet: trade_history_25007.csv
# ✅ CSV→Parquet: trade_history_8519.csv
# ✅ CSV→Parquet: trade_history_113554.csv
# ✅ CSV→Parquet: trade_history_12873.csv
# ✅ CSV→Parquet: trade_history_4323.csv
# ✅ CSV→Parquet: trade_history_108612.csv
# ✅ CSV→Parquet: trade_history_150479.csv
# ✅ CSV→Parquet: trade_history_2752.csv
# ✅ CSV→Parquet: trade_history_111343.csv
# ✅ CSV→Parquet: trade_history_106159.csv
# ✅ CSV→Parquet: trade_history_26268.csv
# ✅ CSV→Parquet: trade_history_2034.csv
# ✅ CSV→Parquet: trade_history_117054.csv
# ✅ CSV→Parquet: trade_history_5983.csv
# ✅ CSV→Parquet: trade_history_100528.csv
# ✅ CSV→Parquet: trade_history_4445.csv
# ✅ CSV→Parquet: trade_history_107247.csv
# ✅ CSV→Parquet: trade_history_18386.csv
# ✅ CSV→Parquet: trade_history_125958.csv
# ✅ CSV→Parquet: trade_history_135593.csv
# ✅ CSV→Parquet: trade_history_25761.csv
# ✅ CSV→Parquet: trade_history_104996.csv
# ✅ CSV→Parquet: trade_history_9161.csv
# ✅ CSV→Parquet: trade_history_105450.csv
# ✅ CSV→Parquet: trade_history_8928.csv
# ✅ CSV→Parquet: trade_history_13984.csv
# ✅ CSV→Parquet: trade_history_14033.csv
# ✅ CSV→Parquet: trade_history_175438.csv
# ✅ CSV→Parquet: trade_history_6905.csv
# ✅ CSV→Parquet: trade_history_10255.csv
# ✅ CSV→Parquet: trade_history_140483.csv
# ✅ CSV→Parquet: trade_history_16624.csv
# ✅ CSV→Parquet: trade_history_26081.csv
# ✅ CSV→Parquet: trade_history_16142.csv
# ✅ CSV→Parquet: trade_history_126060.csv
# ✅ CSV→Parquet: trade_history_111814.csv
# ✅ CSV→Parquet: trade_history_14755.csv
# ✅ CSV→Parquet: trade_history_8096.csv
# ✅ CSV→Parquet: trade_history_9388.csv
# ✅ CSV→Parquet: trade_history_152939.csv
# ✅ CSV→Parquet: trade_history_144183.csv
# ✅ CSV→Parquet: trade_history_122206.csv
# ✅ CSV→Parquet: trade_history_25588.csv
# ✅ CSV→Parquet: trade_history_105875.csv
# ✅ CSV→Parquet: trade_history_24682.csv
# ✅ CSV→Parquet: trade_history_8082.csv
# ✅ CSV→Parquet: trade_history_1918.csv
# ✅ CSV→Parquet: trade_history_114978.csv
# ✅ CSV→Parquet: trade_history_144197.csv
# ✅ CSV→Parquet: trade_history_11639.csv
# ✅ CSV→Parquet: trade_history_26095.csv
# ✅ CSV→Parquet: trade_history_109097.csv
# ✅ CSV→Parquet: trade_history_16156.csv
# ✅ CSV→Parquet: trade_history_108389.csv
# ✅ CSV→Parquet: trade_history_10527.csv
# ✅ CSV→Parquet: trade_history_111800.csv
# ✅ CSV→Parquet: trade_history_10241.csv
# ✅ CSV→Parquet: trade_history_109929.csv
# ✅ CSV→Parquet: trade_history_19503.csv
# ✅ CSV→Parquet: trade_history_118824.csv
# ✅ CSV→Parquet: trade_history_3869.csv
# ✅ CSV→Parquet: trade_history_16630.csv
# ✅ CSV→Parquet: trade_history_139632.csv
# ✅ CSV→Parquet: trade_history_23853.csv
# ✅ CSV→Parquet: trade_history_15339.csv
# ✅ CSV→Parquet: trade_history_124105.csv
# ✅ CSV→Parquet: trade_history_134316.csv
# ✅ CSV→Parquet: trade_history_13748.csv
# ✅ CSV→Parquet: trade_history_6911.csv
# ✅ CSV→Parquet: trade_history_3699.csv
# ✅ CSV→Parquet: trade_history_127424.csv
# ✅ CSV→Parquet: trade_history_17506.csv
# ✅ CSV→Parquet: trade_history_26903.csv
# ✅ CSV→Parquet: trade_history_116821.csv
# ✅ CSV→Parquet: trade_history_3841.csv
# ✅ CSV→Parquet: trade_history_131246.csv
# ✅ CSV→Parquet: trade_history_2587.csv
# ✅ CSV→Parquet: trade_history_11177.csv
# ✅ CSV→Parquet: trade_history_8914.csv
# ✅ CSV→Parquet: trade_history_15311.csv
# ✅ CSV→Parquet: trade_history_102854.csv
# ✅ CSV→Parquet: trade_history_113781.csv
# ✅ CSV→Parquet: trade_history_993.csv
# ✅ CSV→Parquet: trade_history_165617.csv
# ✅ CSV→Parquet: trade_history_103592.csv
# ✅ CSV→Parquet: trade_history_13006.csv
# ✅ CSV→Parquet: trade_history_7399.csv
# ✅ CSV→Parquet: trade_history_14769.csv
# ✅ CSV→Parquet: trade_history_114950.csv
# ✅ CSV→Parquet: trade_history_115496.csv
# ✅ CSV→Parquet: trade_history_11611.csv
# ✅ CSV→Parquet: trade_history_107092.csv
# ✅ CSV→Parquet: trade_history_138262.csv
# ✅ CSV→Parquet: trade_history_19259.csv
# ✅ CSV→Parquet: trade_history_128065.csv
# ✅ CSV→Parquet: trade_history_120439.csv
# ✅ CSV→Parquet: trade_history_1924.csv
# ✅ CSV→Parquet: trade_history_114944.csv
# ✅ CSV→Parquet: trade_history_122548.csv
# ✅ CSV→Parquet: trade_history_8900.csv
# ✅ CSV→Parquet: trade_history_133445.csv
# ✅ CSV→Parquet: trade_history_987.csv
# ✅ CSV→Parquet: trade_history_13774.csv
# ✅ CSV→Parquet: trade_history_103586.csv
# ✅ CSV→Parquet: trade_history_17512.csv
# ✅ CSV→Parquet: trade_history_150860.csv
# ✅ CSV→Parquet: trade_history_26917.csv
# ✅ CSV→Parquet: trade_history_3855.csv
# ✅ CSV→Parquet: trade_history_101391.csv
# ✅ CSV→Parquet: trade_history_107938.csv
# ✅ CSV→Parquet: trade_history_140440.csv
# ✅ CSV→Parquet: trade_history_5217.csv
# ✅ CSV→Parquet: trade_history_111169.csv
# ✅ CSV→Parquet: trade_history_11188.csv
# ✅ CSV→Parquet: trade_history_26724.csv
# ✅ CSV→Parquet: trade_history_2578.csv
# ✅ CSV→Parquet: trade_history_10296.csv
# ✅ CSV→Parquet: trade_history_3666.csv
# ✅ CSV→Parquet: trade_history_4109.csv
# ✅ CSV→Parquet: trade_history_108438.csv
# ✅ CSV→Parquet: trade_history_104202.csv
# ✅ CSV→Parquet: trade_history_1071.csv
# ✅ CSV→Parquet: trade_history_112460.csv
# ✅ CSV→Parquet: trade_history_163299.csv
# ✅ CSV→Parquet: trade_history_22542.csv
# ✅ CSV→Parquet: trade_history_13947.csv
# ✅ CSV→Parquet: trade_history_112306.csv
# ✅ CSV→Parquet: trade_history_22224.csv
# ✅ CSV→Parquet: trade_history_6078.csv
# ✅ CSV→Parquet: trade_history_102115.csv
# ✅ CSV→Parquet: trade_history_115469.csv
# ✅ CSV→Parquet: trade_history_135961.csv
# ✅ CSV→Parquet: trade_history_113018.csv
# ✅ CSV→Parquet: trade_history_159677.csv
# ✅ CSV→Parquet: trade_history_11836.csv
# ✅ CSV→Parquet: trade_history_121914.csv
# ✅ CSV→Parquet: trade_history_110511.csv
# ✅ CSV→Parquet: trade_history_100702.csv
# ✅ CSV→Parquet: trade_history_3100.csv
# ✅ CSV→Parquet: trade_history_5571.csv
# ✅ CSV→Parquet: trade_history_16181.csv
# ✅ CSV→Parquet: trade_history_107079.csv
# ✅ CSV→Parquet: trade_history_11822.csv
# ✅ CSV→Parquet: trade_history_3114.csv
# ✅ CSV→Parquet: trade_history_100716.csv
# ✅ CSV→Parquet: trade_history_26056.csv
# ✅ CSV→Parquet: trade_history_176858.csv
# ✅ CSV→Parquet: trade_history_119247.csv
# ✅ CSV→Parquet: trade_history_101408.csv
# ✅ CSV→Parquet: trade_history_5565.csv
# ✅ CSV→Parquet: trade_history_16195.csv
# ✅ CSV→Parquet: trade_history_22230.csv
# ✅ CSV→Parquet: trade_history_112312.csv
# ✅ CSV→Parquet: trade_history_174097.csv
# ✅ CSV→Parquet: trade_history_102101.csv
# ✅ CSV→Parquet: trade_history_153428.csv
# ✅ CSV→Parquet: trade_history_24641.csv
# ✅ CSV→Parquet: trade_history_14782.csv
# ✅ CSV→Parquet: trade_history_8041.csv
# ✅ CSV→Parquet: trade_history_104570.csv
# ✅ CSV→Parquet: trade_history_978.csv
# ✅ CSV→Parquet: trade_history_23648.csv
# ✅ CSV→Parquet: trade_history_8727.csv
# ✅ CSV→Parquet: trade_history_102667.csv
# ✅ CSV→Parquet: trade_history_1065.csv
# ✅ CSV→Parquet: trade_history_25239.csv
# ✅ CSV→Parquet: trade_history_9439.csv
# ✅ CSV→Parquet: trade_history_22556.csv
# ✅ CSV→Parquet: trade_history_112474.csv
# ✅ CSV→Parquet: trade_history_123871.csv
# ✅ CSV→Parquet: trade_history_109732.csv
# ✅ CSV→Parquet: trade_history_157128.csv
# ✅ CSV→Parquet: trade_history_10282.csv
# ✅ CSV→Parquet: trade_history_151559.csv
# ✅ CSV→Parquet: trade_history_3672.csv
# ✅ CSV→Parquet: trade_history_950.csv
# ✅ CSV→Parquet: trade_history_102897.csv
# ✅ CSV→Parquet: trade_history_25211.csv
# ✅ CSV→Parquet: trade_history_788.csv
# ✅ CSV→Parquet: trade_history_105120.csv
# ✅ CSV→Parquet: trade_history_6722.csv
# ✅ CSV→Parquet: trade_history_3882.csv
# ✅ CSV→Parquet: trade_history_101346.csv
# ✅ CSV→Parquet: trade_history_148020.csv
# ✅ CSV→Parquet: trade_history_26718.csv
# ✅ CSV→Parquet: trade_history_126921.csv
# ✅ CSV→Parquet: trade_history_118617.csv
# ✅ CSV→Parquet: trade_history_120388.csv
# ✅ CSV→Parquet: trade_history_107737.csv
# ✅ CSV→Parquet: trade_history_4135.csv
# ✅ CSV→Parquet: trade_history_156578.csv
# ✅ CSV→Parquet: trade_history_4653.csv
# ✅ CSV→Parquet: trade_history_107051.csv
# ✅ CSV→Parquet: trade_history_18190.csv
# ✅ CSV→Parquet: trade_history_27360.csv
# ✅ CSV→Parquet: trade_history_117242.csv
# ✅ CSV→Parquet: trade_history_2222.csv
# ✅ CSV→Parquet: trade_history_101420.csv
# ✅ CSV→Parquet: trade_history_111633.csv
# ✅ CSV→Parquet: trade_history_6044.csv
# ✅ CSV→Parquet: trade_history_105646.csv
# ✅ CSV→Parquet: trade_history_22218.csv
# ✅ CSV→Parquet: trade_history_115455.csv
# ✅ CSV→Parquet: trade_history_102129.csv
# ✅ CSV→Parquet: trade_history_14972.csv
# ✅ CSV→Parquet: trade_history_24669.csv
# ✅ CSV→Parquet: trade_history_103237.csv
# ✅ CSV→Parquet: trade_history_8069.csv
# ✅ CSV→Parquet: trade_history_6050.csv
# ✅ CSV→Parquet: trade_history_9363.csv
# ✅ CSV→Parquet: trade_history_115441.csv
# ✅ CSV→Parquet: trade_history_103223.csv
# ✅ CSV→Parquet: trade_history_23112.csv
# ✅ CSV→Parquet: trade_history_107045.csv
# ✅ CSV→Parquet: trade_history_4647.csv
# ✅ CSV→Parquet: trade_history_3128.csv
# ✅ CSV→Parquet: trade_history_27374.csv
# ✅ CSV→Parquet: trade_history_101434.csv
# ✅ CSV→Parquet: trade_history_2236.csv
# ✅ CSV→Parquet: trade_history_109068.csv
# ✅ CSV→Parquet: trade_history_5559.csv
# ✅ CSV→Parquet: trade_history_3896.csv
# ✅ CSV→Parquet: trade_history_2550.csv
# ✅ CSV→Parquet: trade_history_101352.csv
# ✅ CSV→Parquet: trade_history_117530.csv
# ✅ CSV→Parquet: trade_history_27412.csv
# ✅ CSV→Parquet: trade_history_4121.csv
# ✅ CSV→Parquet: trade_history_102883.csv
# ✅ CSV→Parquet: trade_history_23674.csv
# ✅ CSV→Parquet: trade_history_944.csv
# ✅ CSV→Parquet: trade_history_115327.csv
# ✅ CSV→Parquet: trade_history_6736.csv
# ✅ CSV→Parquet: trade_history_105134.csv
# ✅ CSV→Parquet: trade_history_9405.csv
# ✅ CSV→Parquet: trade_history_112448.csv

# %%
import duckdb, glob, os

# ─── 환경 설정 ─────────────────────────────────────────────────
home        = os.path.expanduser("~")
raw         = os.path.join(home, "dev/RETrend/tmp/raw")
parquet_dir = os.path.join(home, "dev/RETrend/parquet")
os.makedirs(parquet_dir, exist_ok=True)

con = duckdb.connect()

# ─── (B) complex_list.csv → Parquet ────────────────────────────
complex_csv = os.path.join(raw, "complex_list.csv")
complex_pq  = os.path.join(parquet_dir, "complex_list.parquet")

con.execute(f"""
COPY (
  SELECT
    CAST(complexNo              AS BIGINT)  AS complexNo,
    complexName::VARCHAR                       AS complexName,
    CAST(cortarNo               AS BIGINT)    AS cortarNo,
    realEstateTypeCode::VARCHAR                AS realEstateTypeCode,
    realEstateTypeName::VARCHAR                AS realEstateTypeName,
    detailAddress::VARCHAR                     AS detailAddress,
    CAST(latitude              AS DOUBLE)     AS latitude,
    CAST(longitude             AS DOUBLE)     AS longitude,
    CAST(totalHouseholdCount   AS BIGINT)    AS totalHouseholdCount,
    CAST(totalBuildingCount    AS BIGINT)    AS totalBuildingCount,
    CAST(highFloor             AS BIGINT)    AS highFloor,
    CAST(lowFloor              AS BIGINT)    AS lowFloor,
    useApproveYmd::VARCHAR                     AS useApproveYmd,
    CAST(dealCount             AS BIGINT)    AS dealCount,
    CAST(leaseCount            AS BIGINT)    AS leaseCount,
    CAST(rentCount             AS BIGINT)    AS rentCount,
    CAST(shortTermRentCount    AS BIGINT)    AS shortTermRentCount,
    CAST(isInterest            AS BOOLEAN)    AS isInterest,
    cortarAddress::VARCHAR                      AS cortarAddress,
    CAST(tourExist             AS BOOLEAN)    AS tourExist,
    CAST(eupmeandongCortarNo   AS BIGINT)     AS eupmeandongCortarNo,
    eupmeandongCortarName::VARCHAR              AS eupmeandongCortarName
  FROM read_csv_auto('{complex_csv}')
)
TO '{complex_pq}' (FORMAT PARQUET, COMPRESSION 'snappy');
""")
print("✅ CSV→Parquet: complex_list.csv →", complex_pq)

con.close()
# Out:
# ✅ CSV→Parquet: complex_list.csv → /Users/dave/dev/RETrend/parquet/complex_list.parquet

# %%
from pyspark.sql import SparkSession
import os

home = os.path.expanduser("~")
warehouse = f"file://{os.path.join(home, 'dev/RETrend/tmp/raw/iceberg/phase2_default')}"

spark = (
    SparkSession.builder
    .appName("IcebergHiveCatalogPhase2")
    .config("spark.jars.packages", "org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.5.2")
    .config("spark.sql.extensions", "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions")
    .config("spark.sql.catalog.hive", "org.apache.iceberg.spark.SparkCatalog")
    .config("spark.sql.catalog.hive.catalog-impl", "org.apache.iceberg.hive.HiveCatalog")
    .config("spark.sql.catalog.hive.uri", "thrift://localhost:9083")
    .config("spark.sql.catalog.hive.warehouse", warehouse)
    .config("spark.sql.parquet.enableVectorizedReader", "false")
    .config("spark.sql.iceberg.vectorization.enabled", "false")
    .getOrCreate()
)

# %%
#spark.sql("DROP DATABASE IF EXISTS hive.phase2 CASCADE")

# %%
spark.sql("""
CREATE DATABASE IF NOT EXISTS hive.phase2_1
LOCATION 'file:/Users/dave/dev/RETrend/tmp/raw/iceberg/phase2_1_default'
""")
# Out:
# DataFrame[]

# %%
spark.sql("DESCRIBE DATABASE EXTENDED hive.phase2_1").show(truncate=False)
# Out:
# +--------------+---------------------------------------------------------------------------------+
# |info_name     |info_value                                                                       |
# +--------------+---------------------------------------------------------------------------------+
# |Catalog Name  |hive                                                                             |
# |Namespace Name|phase2_1                                                                         |
# |Location      |file:/Users/dave/dev/RETrend/tmp/raw/iceberg/phase2_1_default                    |
# |Owner         |dave                                                                             |
# |Properties    |((hive.metastore.database.owner,dave), (hive.metastore.database.owner-type,USER))|
# +--------------+---------------------------------------------------------------------------------+

# %%
from pyspark.sql.types import *

# Parquet 경로
parquet_dir = os.path.join(home, "dev/RETrend/parquet")

# trade_history 스키마
trade_schema = StructType([
    StructField("tradeType", StringType(), True),
    StructField("tradeYear", LongType(), True),
    StructField("tradeMonth", LongType(), True),
    StructField("tradeDate", LongType(), True),
    StructField("dealPrice", LongType(), True),
    StructField("floor", LongType(), True),
    StructField("representativeArea", DoubleType(), True),
    StructField("exclusiveArea", DoubleType(), True),
    StructField("formattedPrice", StringType(), True),
    StructField("formattedTradeYearMonth", StringType(), True),
    StructField("areaNo", LongType(), True),
    StructField("complexNo", LongType(), True),
    StructField("date", TimestampType(), True),
])

trade_df = (
    spark.read.schema(trade_schema)
        .parquet(f"{parquet_dir}/trade_history_*.parquet")
)

# 테이블 생성
spark.sql("DROP TABLE IF EXISTS hive.phase2_1.trade_history")
trade_df.writeTo("hive.phase2_1.trade_history") \
        .using("iceberg") \
        .createOrReplace()

# %%
# complex_list 스키마
complex_schema = StructType([
    StructField("complexNo", LongType(), True),
    StructField("complexName", StringType(), True),
    StructField("cortarNo", LongType(), True),
    StructField("realEstateTypeCode", StringType(), True),
    StructField("realEstateTypeName", StringType(), True),
    StructField("detailAddress", StringType(), True),
    StructField("latitude", DoubleType(), True),
    StructField("longitude", DoubleType(), True),
    StructField("totalHouseholdCount", LongType(), True),
    StructField("totalBuildingCount", LongType(), True),
    StructField("highFloor", LongType(), True),
    StructField("lowFloor", LongType(), True),
    StructField("useApproveYmd", StringType(), True),
    StructField("dealCount", LongType(), True),
    StructField("leaseCount", LongType(), True),
    StructField("rentCount", LongType(), True),
    StructField("shortTermRentCount", LongType(), True),
    StructField("isInterest", BooleanType(), True),
    StructField("cortarAddress", StringType(), True),
    StructField("tourExist", BooleanType(), True),
    StructField("eupmeandongCortarNo", LongType(), True),
    StructField("eupmeandongCortarName", StringType(), True),
])

complex_df = (
    spark.read.schema(complex_schema)
        .parquet(f"{parquet_dir}/complex_list.parquet")
)

spark.sql("DROP TABLE IF EXISTS hive.phase2_1.complex_info")
complex_df.writeTo("hive.phase2_1.complex_info") \
          .using("iceberg") \
          .createOrReplace()

# %%
spark.sql("SHOW TABLES IN hive.phase2_1").show()
# Out:
# +---------+-------------+-----------+
# |namespace|    tableName|isTemporary|
# +---------+-------------+-----------+
# | phase2_1|trade_history|      false|
# | phase2_1| complex_info|      false|
# +---------+-------------+-----------+

# %%
joined_df = spark.sql("""
  SELECT
    t.date,
    t.tradeType,
    t.dealPrice,
    t.floor,
    t.representativeArea,
    t.exclusiveArea,
    t.formattedPrice,
    t.formattedTradeYearMonth,
    c.complexName,
    c.latitude,
    c.longitude
  FROM hive.phase2_1.trade_history t
  LEFT JOIN hive.phase2_1.complex_info c
    ON t.complexNo = c.complexNo
  ORDER BY t.date DESC
  LIMIT 20
""")
joined_df.show(truncate=False)
# Out:
# [Stage 23:===========================>                         (111 + 13) / 217]
# +-------------------+---------+---------+-----+------------------+-------------+--------------+-----------------------+---------------------------+---------+----------+
# |date               |tradeType|dealPrice|floor|representativeArea|exclusiveArea|formattedPrice|formattedTradeYearMonth|complexName                |latitude |longitude |
# +-------------------+---------+---------+-----+------------------+-------------+--------------+-----------------------+---------------------------+---------+----------+
# |2025-07-19 09:00:00|A1       |12000    |15   |0.0               |0.0          |1억 2,000     |2025-07-19             |삼익세라믹                 |36.624597|127.478865|
# |2025-07-18 09:00:00|A1       |16000    |9    |0.0               |0.0          |1억 6,000     |2025-07-18             |나이스타운12차(도시형)     |36.358901|127.34855 |
# |2025-07-18 09:00:00|A1       |49600    |5    |0.0               |0.0          |4억 9,600     |2025-07-18             |운암자이포레나퍼스티체1단지|35.181913|126.877026|
# |2025-07-18 09:00:00|A1       |27000    |4    |0.0               |0.0          |2억 7,000     |2025-07-18             |현대프라힐스원주혁신       |37.32128 |127.977636|
# |2025-07-18 09:00:00|A1       |5100     |6    |0.0               |0.0          |5,100         |2025-07-18             |한빛                       |37.011151|127.49415 |
# |2025-07-18 09:00:00|A1       |27000    |4    |0.0               |0.0          |2억 7,000     |2025-07-18             |현대프라힐스원주혁신       |37.32128 |127.977636|
# |2025-07-18 09:00:00|A1       |86660    |26   |0.0               |0.0          |8억 6,660     |2025-07-18             |문수로푸르지오어반피스     |35.535667|129.305888|
# |2025-07-18 09:00:00|A1       |14000    |7    |0.0               |0.0          |1억 4,000     |2025-07-18             |상인보라2차                |35.80976 |128.545585|
# |2025-07-18 09:00:00|A1       |7800     |5    |0.0               |0.0          |7,800         |2025-07-18             |정암문백                   |36.7832  |127.434111|
# |2025-07-18 09:00:00|A1       |6000     |7    |0.0               |0.0          |6,000         |2025-07-18             |꿈의궁전                   |38.125953|128.207161|
# |2025-07-18 09:00:00|A1       |41700    |15   |0.0               |0.0          |4억 1,700     |2025-07-18             |상무한국아델리움           |35.158256|126.867109|
# |2025-07-18 09:00:00|A1       |42000    |3    |0.0               |0.0          |4억 2,000     |2025-07-18             |동대구더센트로데시앙       |35.87749 |128.613908|
# |2025-07-18 09:00:00|A1       |27800    |9    |0.0               |0.0          |2억 7,800     |2025-07-18             |첫마을2단지퍼스트프라임    |36.481138|127.260033|
# |2025-07-18 09:00:00|A1       |118000   |8    |0.0               |0.0          |11억 8,000    |2025-07-18             |수성범어더블유(주상복합)   |35.858094|128.628612|
# |2025-07-18 09:00:00|A1       |42800    |27   |0.0               |0.0          |4억 2,800     |2025-07-18             |한신더휴이스턴팰리스       |35.905808|128.54476 |
# |2025-07-18 09:00:00|A1       |50275    |5    |0.0               |0.0          |5억 275       |2025-07-18             |더샵소양스타리버           |37.887859|127.725978|
# |2025-07-18 09:00:00|A1       |2320     |5    |0.0               |0.0          |2,320         |2025-07-18             |동해규수방                 |37.49318 |129.05569 |
# |2025-07-18 09:00:00|A1       |34500    |4    |0.0               |0.0          |3억 4,500     |2025-07-18             |선운지구진아리채           |35.149851|126.7728  |
# |2025-07-18 09:00:00|A1       |20000    |4    |0.0               |0.0          |2억           |2025-07-18             |한라훼미리                 |35.521611|129.314334|
# |2025-07-18 09:00:00|A1       |61000    |24   |0.0               |0.0          |6억 1,000     |2025-07-18             |더샵번영센트로             |35.528605|129.332067|
# +-------------------+---------+---------+-----+------------------+-------------+--------------+-----------------------+---------------------------+---------+----------+

# %% [markdown]
# ---
#
# 1. Write MERGE into Iceberg 개선
# 2. Airflow 용 Dag

# %%
# from pyspark.sql import SparkSession
# from pyspark.sql.functions import col
# import argparse

# parser = argparse.ArgumentParser()
# parser.add_argument("--date", required=True)
# args = parser.parse_args()
# process_date = args.date

# spark = (
#     SparkSession.builder
#     .appName("ParquetToIcebergMerge")
#     .config("spark.sql.catalog.my_catalog", "org.apache.iceberg.spark.SparkCatalog")
#     .config("spark.sql.catalog.my_catalog.type", "hive")
#     .config("spark.sql.catalog.my_catalog.uri", "thrift://hive-metastore:9083")
#     .getOrCreate()
# )

# # Read Parquet data
# parquet_df = spark.read.parquet(f"s3a://your-bucket/parquet/dt={process_date}")

# # Write MERGE into Iceberg
# (
#     parquet_df
#     .writeTo("my_catalog.db.estate_price")
#     .option("overwrite-mode", "dynamic")  # For MERGE semantics
#     .overwritePartitions()
# )

# %%
# from airflow import DAG
# from airflow.providers.apache.spark.operators.spark_submit import SparkSubmitOperator
# from datetime import datetime

# default_args = {
#     'owner': 'airflow',
#     'start_date': datetime(2024, 1, 1),
# }

# with DAG(
#     dag_id='iceberg_parquet_merge',
#     default_args=default_args,
#     schedule_interval='@daily',
#     catchup=False,
# ) as dag:

#     merge_task = SparkSubmitOperator(
#         task_id='spark_merge_parquet_to_iceberg',
#         application='/mnt/nfs/spark-jobs/parquet_to_iceberg.py',
#         conn_id='spark_default',
#         conf={
#             'spark.sql.catalog.my_catalog': 'org.apache.iceberg.spark.SparkCatalog',
#             'spark.sql.catalog.my_catalog.type': 'hive',
#             'spark.sql.catalog.my_catalog.uri': 'thrift://hive-metastore:9083',
#             'spark.sql.iceberg.vectorization.enabled': 'true',
#             'spark.executor.memory': '4g',
#             'spark.driver.memory': '2g'
#         },
#         master='spark://spark-master:7077',
#         application_args=[
#             '--date', '{{ ds }}'
#         ],
#         verbose=True
#     )
